# %%
import re
import random
import pandas as pd

# %%
AGE_CHAR = [
    'novantanove',
    'novantotto',
    'novantasette',
    'novantasei',
    'novantacinque',
    'novantaquattro',
    'novantatre',
    'novantadue',
    'novantuno',
    'novanta',
    'ottantanove',
    'ottantotto',
    'ottantasette',
    'ottantasei',
    'ottantacinque',
    'ottantaquattro',
    'ottantatre',
    'ottantadue',
    'ottantuno',
    'ottanta',
    'settantanove',
    'settantotto',
    'settantasette',
    'settantasei',
    'settantacinque',
    'settantaquattro',
    'settantatre',
    'settantadue',
    'settantuno',
    'settanta',
    'sessantanove',
    'sessantotto',
    'sessantasette',
    'sessantasei',
    'sessantacinque',
    'sessantaquattro',
    'sessantatre',
    'sessantadue',
    'sessantuno',
    'sessanta',
    'cinquantanove',
    'cinquantotto',
    'cinquantasette',
    'cinquantasei',
    'cinquantacinque',
    'cinquantaquattro',
    'cinquantatre',
    'cinquantadue',
    'cinquantuno',
    'cinquanta',
    'quarantanove',
    'quarantotto',
    'quarantasette',
    'quarantasei',
    'quarantacinque',
    'quarantaquattro',
    'quarantatre',
    'quarantadue',
    'quarantuno',
    'quaranta',
    'trentanove',
    'trentotto',
    'trentasette',
    'trentasei',
    'trentacinque',
    'trentaquattro',
    'trentatre',
    'trentadue',
    'trentuno',
    'trenta',
    'ventinove',
    'ventotto',
    'ventisette',
    'ventisei',
    'venticinque',
    'ventiquattro',
    'ventitre',
    'ventidue',
    'ventuno',
    'venti',
    'diciannove',
    'diciotto',
    'diciassette',
    'sedici',
    'quindici',
    'quattordici',
    'tredici'
 ]

# remove last letter of each years_in_words entry, in order to match both
# the noun ("ventiquattro") and the adjective ("ventiquattrenne")
AGE_CHAR_SUFFIX_LONG = [year[:-1] for year in AGE_CHAR]

# keep only the shortest form as a first filter
AGE_CHAR_SUFFIX_SHORT = [
    "tredic",
    "quattordic",
    "quindic",
    "sedic",
    "diciasset",
    "diciott",
    "diciannov",
    "vent",
    "trent",
    "quarant",
    "cinquant",
    "sessant",
    "settant",
    "ottant",
    "novant",
]

AGE_DIGIT = list(range(99,12,-1))

# List of regex patterns for matching Twitter posts mentioning the age of the user
# The patterns are built using the age expressed in digits (e.g. "22" for 22)
AGE_DIGIT_PATTERNS = [
    # Matches phrases like "ho compiuto 22 anni" (I just turned 22)
    # but not "quando ho compiuto 22 anni" (when I turned 22)
    # nor "ho compiuto 22 anni di/de" (I have 22 years of)
    r"(?<!quando\s)(?<!quando)ho\s*compiuto\s*(\d{2})\s*anni(?! su)(?! più)(?! da)(?! de)(?! di)(?!de)(?!di)(?!su)(?!più)(?!da)(?! in più)(?! in meno)",
    r"\bcompio\s*(\d{2})\s*anni(?! su)(?! più)(?! da)(?! de)(?! di)(?!de)(?!di)(?!su)(?!più)(?!da)(?! in più)(?! in meno)",
    # Matches phrases like "ho 22 anni" (I am 22 years old)
    # but not "da quando/non ho 22 anni" (since I am / I am not 22 years old)
    # nor "ho 22 anni di/de" (I have 22 years of)
    # nor "se ho 22 anni" (if I am 22 years old)
    r"(?<!quando\s)(?<!quando)(?<!non\s)(?<!non)(?<!se\s)(?<!se)ho\s*(\d{2})\s*anni(?! su)(?! più)(?! da)(?! de)(?! di)(?!de)(?!di)(?!su)(?!più)(?!da)(?! in più)(?! in meno)",
    # Matches phrases like "faccio 22 anni" (I am turning 22 years old)
    # but not "faccio 22 anni di/de" (I have 22 years of)
    r"\bfaccio\s*(\d{2})\s*anni(?! che)(?! su)(?! più)(?! da)(?! de)(?! di)(?!de)(?!di)(?!su)(?!più)(?!da)(?! in più)(?! in meno)(?!che)",
    # Matches phrases like "spengo 22 candeline" (I am blowing 22 candles)
    r"\bspengo\s*(\d{2})\s*candeline",
    # Matches phrases like "il mio 22^ compleanno" (my 22nd birthday)
    r"il\s*mio\s*(\d{2})\^\s*comple(?:anno)?",
    # Matches phrases like "sono un 22enne" (I am a 22-year-old...)
    r"\bsono\s*una?\s*(\d{2})\s*enne",
    # Matches phrases like "i miei 22 anni" (my 22 years)
    # r"\bmiei\s*(\d{2})\s*anni",
]

YEAR_OF_BIRTH_PATTERNS = [
    # Matches sentences like "sono nato nel 1993/93/'93" (I was born in 1993)
    r"\bsono\s*nato\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bsono\s*nata\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono del 1993/93/'93" (I am from 1993)
    # r"sono\s*del\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono un 1993/93/'93" (I am a 1993)
    # r"sono\s*una?\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono della generazione 1993/93/'93" (I am generation 1993)
    r"sono\s*della\s*generazione\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono classe 1993/93/'93" (I am class 1993)
    r"sono\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"sono\s*una?\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
]

YEAR_OF_BIRTH_PATTERNS_BIO = [
    # Matches sentences like "sono nato nel 1993/93/'93" (I was born in 1993)
    r"\bsono\s*nato\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bsono\s*nata\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bnato\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bnata\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bborn\s*in\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono del 1993/93/'93" (I am from 1993)
    r"sono\s*del\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono un 1993/93/'93" (I am a 1993)
    r"sono\s*una?\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono della generazione 1993/93/'93" (I am generation 1993)
    r"sono\s*della\s*generazione\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bgenerazione\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono classe 1993/93/'93" (I am class 1993)
    r"sono\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"sono\s*una?\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bclasse\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
]

def return_full_age_char_pattern(age_char):
    """
    Returns a list of regex patterns for matching Twitter posts mentioning the age of the user.
    The patterns are built using the age_char parameter, which is a string containing the
    Italian word for the age of the user (e.g. "ventidue" for 22).
    """
    age_char_patterns = [
            # Matches phrases like "ho compiuto ventidue anni" (I just turned twenty-two)
            # but not "quando ho compiuto ventidue anni" (when I turned twenty-two)
            # nor "ho compiuto ventidue anni di/de" (I have twenty-two years of)
            r"(?<!quando\s)(?<!quando)ho\s*compiuto\s*({}).*\s*anni(?! de)(?!de)(?! di)(?!di)(?! in più)(?! in meno)".format(age_char),
            r"\bcompio\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)".format(age_char),
            # Matches phrases like "ho ventidue anni" (I am twenty-two years old),
            # but not "a quando/non ho ventidue anni" (since I am / I am not twenty-two years old)
            # nor "ho ventidue anni di/de" (I have twenty-two years of)
            # nor "se ho ventidue anni" (if I am twenty-two years old)
            r"(?<!quando\s)(?<!quando)(?<!non\s)(?<!non)(?<!se\s)(?<!se)ho\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)(?! in più)(?! in meno)".format(age_char),
            # Matches phrases like "faccio ventidue anni" (I am turning twenty-two years old)
            r"\bfaccio\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)".format(age_char),
            # Matches phrases like "spengo ventidue candeline" (I am blowing twenty-two candles)
            r"\bspengo\s*({})\s*candeline".format(age_char),
            # Matches phrases like "mio ventiduesimo comple/compleanno" (my twenty-second birthday)
            r"il\s*mio\s*{}e?simo\s*comple(?:anno)?".format(age_char),
            # Matches phrases like "sono un ventiduenne" (I am twenty-two-years-old...)
            r"\bsono\s*una?\s*({})\s*e?nne".format(age_char),
            # Matches phrases like "i miei ventidue anni" (my twenty-two years)
            # r"\bmiei\s*({}).*\s*anni".format(age_char),
        ]
    return age_char_patterns

def remove_age_pattern(text):

    # check if the tweet contains a double digit number, but not in a quoted text
    if re.search(r"\d{2}", text):
        if not re.search(r"\".*\d{2}.*\"", text) \
            and not re.search(r"\“.*\d{2}.*\”", text) \
            and not re.search(r"\«.*\d{2}.*\»", text):
            
            # search for year of birth patterns
            for pattern in AGE_DIGIT_PATTERNS:
                pattern = "(" + pattern + ")"
                newtext = re.sub(pattern, "", text, flags=re.IGNORECASE)
                if newtext != text:
                    return newtext

            # search for year of birth patterns
            for pattern in YEAR_OF_BIRTH_PATTERNS:
                pattern = "(" + pattern + ")"
                newtext = re.sub(pattern, "", text, flags=re.IGNORECASE)
                if newtext != text:
                    return newtext

            # search for year of birth patterns
            for pattern in YEAR_OF_BIRTH_PATTERNS_BIO:
                pattern = "(" + pattern + ")"
                newtext = re.sub(pattern, "", text, flags=re.IGNORECASE)
                if newtext != text:
                    return newtext

    # check if the text contains an age expressed in characters
    if re.search(r"{}".format("|".join(AGE_CHAR_SUFFIX_SHORT)), text, flags=re.IGNORECASE):
            # check what age is expressed in the text and retrieve its index
            matching_age_char = re.findall(r"{}".format("|".join(AGE_CHAR_SUFFIX_LONG)), text, flags=re.IGNORECASE)[0].lower()
            matching_age_char_index = AGE_CHAR_SUFFIX_LONG.index(matching_age_char)
            # check if the age is not in a quoted text
            if not re.search(r"\".*{}.*\"".format(matching_age_char), text, flags=re.IGNORECASE) \
                and not re.search(r"\“.*{}.*\”".format(matching_age_char), text, flags=re.IGNORECASE) \
                and not re.search(r"\«.*{}.*\»".format(matching_age_char), text, flags=re.IGNORECASE):
                # check if also the full form of the age is present in the text
                if re.search(r"{}".format(AGE_CHAR[matching_age_char_index]), text, flags=re.IGNORECASE):
                    patterns = return_full_age_char_pattern(AGE_CHAR[matching_age_char_index])
                else:
                    patterns = return_full_age_char_pattern(AGE_CHAR_SUFFIX_LONG[matching_age_char_index])
                # search for age statements and retrieve age
                for pattern in patterns:
                    pattern = "(" + pattern + ")"
                    newtext = re.sub(pattern, "", text, flags=re.IGNORECASE)
                    if newtext != text:
                        return newtext

    return text



# Example tweets with age patterns
tweets_should_match = [
    'ho "compiuto 50 anni" e non mi importa più niente.',
    'ho compiuto 50 anni e non mi importa più niente.',
    "Ieri ho compiuto 60 anni e mi sento freschissimo.",
    "Tra un mese compio 25 anni e non vedo l'ora.",
    "Ormai ho 30 anni, damn...",
    "Finalmente faccio 18 anni!!!",
    "Cosa vuoi che ne sappia di vecchiaia, sono una 28enne...",
    "Spengo 40 candeline domani, che emozione.",
    "Grande fiesta per il mio 22^ comple.",
    "Grande fiesta per il mio 22^ compleanno.",
    "--------------------------------------------------------",
    "Ieri ho compiuto sessanta anni e mi sento freschissimo.",
    "Ieri ho compiuto sessant'anni e mi sento freschissimo.",
    "Tra un mese compio venticinque anni e non vedo l'ora.",
    "Ormai ho trent'anni, damn...",
    "Finalmente faccio diciotto anni!!!",
    "Cosa vuoi che ne sappia di vecchiaia, sono una ventottenne...",
    "Spengo quaranta candeline domani, che emozione.",
    "Grande fiesta per il mio ventiduesimo comple.",
    "Grande fiesta per il mio trentunesimo comple.",
    'Mi sento in diritto di dirlo in quanto sono un ventiduenne.',
    "HO VENTICINQUE ANNI gioventù",
]

# Example tweets with year patterns
tweets_should_match_year = [
    'Sono nato "nel \'52" sai?',
    "Sono nato nel 52 sai?",
    "Sono nato nel 1952 sai?",
    "Sono nato nel 2013 sai?",
    "Sono del '93",
    "Sono del 1966 sai?",
    "Sono del 2000 sai?",
    "Sono un 93",
    "Sono un 2001",
    "Sono un 93 sai?",
    "Sono un '93 sai?",
    "Sono classe '93 sai?",
    "Sono un classe 2000",
    "Ho 20 anni",
    "Ho vent'anni e non me ne frega un cavolo",
]

print("######################## Tweets that should match:")
print()
for tweet in tweets_should_match:
    print(tweet)
    print(remove_age_pattern(tweet))
    print('------------------------------')

print("######################## Tweets that should match:")
print()
for tweet in tweets_should_match_year:
    print(tweet)
    print(remove_age_pattern(tweet))
    print('------------------------------')
# Out:
# ######################## Tweets that should match:
#
# ho "compiuto 50 anni" e non mi importa più niente.
# ho "compiuto 50 anni" e non mi importa più niente.
# ------------------------------
# ho compiuto 50 anni e non mi importa più niente.
#  e non mi importa più niente.
# ------------------------------
# Ieri ho compiuto 60 anni e mi sento freschissimo.
# Ieri  e mi sento freschissimo.
# ------------------------------
# Tra un mese compio 25 anni e non vedo l'ora.
# Tra un mese  e non vedo l'ora.
# ------------------------------
# Ormai ho 30 anni, damn...
# Ormai , damn...
# ------------------------------
# Finalmente faccio 18 anni!!!
# Finalmente !!!
# ------------------------------
# Cosa vuoi che ne sappia di vecchiaia, sono una 28enne...
# Cosa vuoi che ne sappia di vecchiaia, ...
# ------------------------------
# Spengo 40 candeline domani, che emozione.
#  domani, che emozione.
# ------------------------------
# Grande fiesta per il mio 22^ comple.
# Grande fiesta per .
# ------------------------------
# Grande fiesta per il mio 22^ compleanno.
# Grande fiesta per .
# ------------------------------
# --------------------------------------------------------
# --------------------------------------------------------
# ------------------------------
# Ieri ho compiuto sessanta anni e mi sento freschissimo.
# Ieri  e mi sento freschissimo.
# ------------------------------
# Ieri ho compiuto sessant'anni e mi sento freschissimo.
# Ieri  e mi sento freschissimo.
# ------------------------------
# Tra un mese compio venticinque anni e non vedo l'ora.
# Tra un mese  e non vedo l'ora.
# ------------------------------
# Ormai ho trent'anni, damn...
# Ormai , damn...
# ------------------------------
# Finalmente faccio diciotto anni!!!
# Finalmente !!!
# ------------------------------
# Cosa vuoi che ne sappia di vecchiaia, sono una ventottenne...
# Cosa vuoi che ne sappia di vecchiaia, ...
# ------------------------------
# Spengo quaranta candeline domani, che emozione.
#  domani, che emozione.
# ------------------------------
# Grande fiesta per il mio ventiduesimo comple.
# Grande fiesta per .
# ------------------------------
# Grande fiesta per il mio trentunesimo comple.
# Grande fiesta per .
# ------------------------------
# Mi sento in diritto di dirlo in quanto sono un ventiduenne.
# Mi sento in diritto di dirlo in quanto .
# ------------------------------
# HO VENTICINQUE ANNI gioventù
#  gioventù
# ------------------------------
# ######################## Tweets that should match:
#
# Sono nato "nel '52" sai?
# Sono nato "nel '52" sai?
# ------------------------------
# Sono nato nel 52 sai?
# sai?
# ------------------------------
# Sono nato nel 1952 sai?
#  sai?
# ------------------------------
# Sono nato nel 2013 sai?
#  sai?
# ------------------------------
# Sono del '93
#
# ------------------------------
# Sono del 1966 sai?
#  sai?
# ------------------------------
# Sono del 2000 sai?
#  sai?
# ------------------------------
# Sono un 93
#
# ------------------------------
# Sono un 2001
#
# ------------------------------
# Sono un 93 sai?
# sai?
# ------------------------------
# Sono un '93 sai?
# sai?
# ------------------------------
# Sono classe '93 sai?
# sai?
# ------------------------------
# Sono un classe 2000
#
# ------------------------------
# Ho 20 anni
#
# ------------------------------
# Ho vent'anni e non me ne frega un cavolo
#  e non me ne frega un cavolo
# ------------------------------

# %% [markdown]
# # Inspect dataset with removed aged patterns

# %%
import pandas as pd

df = pd.read_pickle('../data/user_classification/data_for_models_test.pkl')

# %%
c = 0
for t in df.long_text[:100]:
    for s in t.split('\n'):
        tt = remove_age_pattern(str(s))
        if tt != s:
            c += 1
            print(s)
            print(tt)
            print('------------------------------')
print(c)
# Out:
# Ho trent’anni e non digerisco più la carne rossa, ci manca qualche allergia ai latticini poi sarà la volta buona per diventare magra.
#  e non digerisco più la carne rossa, ci manca qualche allergia ai latticini poi sarà la volta buona per diventare magra.
# ------------------------------
# 1

# %%
for i in df.masked_bio:
    print(i)
# Out:
# Con le ruote per terra
# Sentire il mio passo sul sentiero
# I Dispersi ed.Falsopiano
# Movimento per 21 pianoforti
# Capulcu, Voices from Gezi
# insolitocinema.it
# Quello che gli altri pensano della tua persona dice molto su di loro ma niente su di te.
# Love me? Great. Hate me? Even better. Think I'm ugly? Don't look at me. Don' know me? Don' judge me. Think you know me? You have no idea...
# Sii il cambiamento che vuoi vedere nel mondo Mahatma Gandhi
# at home I feel like a tourist.
# Digital Life Coach - yourDigital // 26yo, 10k connections, 150k miles/yr // Cyclist // Forbes 30under30
# Autore di 5 libri su innovazione e comunicazione - Anchorman/speaker ad eventi, docente universitario, creator, divulgatore - Lettore e gamer entusiasta
# I want to build intelligent machines.
# Opinions are mine, tweets Twitter's.
#
#
#
# ⚓ Italy ['88] Student | Project Engineer | StreetView Photographer | Traveller | Cocker | ex Dj & PR
#
# 📍Milano / Roma | Fotografa | Una passione irrefrenabile per l’autoritrattistica in toilette
# Galletto romagnolo alla scoperta del mondo
#
# imprenditrice, internet, media e famiglia: insomma un bel divertimento!
#
#
#
# Leggere fra le righe di una politica che non parla chiaro
#
# Ho tre tatuaggi, due gatti, sessanta piante. Rido molto e non mi piace il caffè · 📷 Instagram: personecheleggono
#
# precaria, a tratti disoccupata.
#
# Da grande metterò assieme tutti gli studi di cultura pop che sto conducendo da 26 anni per fare fighissimi commercial pepsi.
# http://t.co/dKw12lFboP
#
#
#
# 自由
# Medico, Procrastinatore inguaribile, Sinistroide Democratico, Sognatore Lucano. Non sono 33, sono 25+IVA !
# .. E allora molla gli ormeggi. Lascia i porti sicuri. Lascia che gli alisei riempiano le tue vele. Esplora. Sogna
#
# She/her 🏳️‍🌈 Nerd fitgirl wannabe based in Milan ~ ~ 不经历风雨怎么见彩虹?!
# @CityUniLondon alumnus, @frontlineclub member, @agenzia_Ansa's European correspondent. Formerly in London and Moscow. Latest book: https://t.co/lWm4k7ksfA
#
# Graduated in foreign languages and communications. Feeling feelings since 1988.
#
# Guardo il mondo e le persone dal mio personalissimo punto di vista e cerco di capire il perché di tutto quello che mi succede intorno.
# 1-💣 🇷🇺 Putin 🤢🤮 2- 🇨🇳 allergic to CCP 3-🤔 Grazie a dio non credo in dio, ma prego dio che esista un Dio 4- 😀Eutanasia legale !! 5-💉ProVax 6-❌ Renziani
# From Florence to Turin.
# Amante del giornalismo di qualità e buongustaio.
# Continuerò sempre a credere che tra bufalo e locomotiva, dovrebbe vincere il bufalo.
#
# Knowledge modelling consultant in digital era.
# Curious that life takes me along the "sanset avenue" to the rebellion that, in my youth, was barely touch.
#
# 3 libri di poesie . Giornalista ex Radio Deejay, ex Radio Capital. Interessi: libri, teatro.
#
# Da piccolissimo, dissi a mia mamma: “Mamma, voglio diventare il Presidente della Repubblica”. Amo la politica, più di ogni altra cosa.
# Acro and aerial enthusiast 🎪 loving Spain&South America, sleeping, drawing and silly things
#
# 🌍 Trapani - Sicily - Italy
# 📰 Journalist
# 💻 Communication
# 🏀 Basketball
# 📻 Radio
# 💻 Nerd
#
# Leone, ascendente Leone
# Italian gal, shopaholic, travel, fashion and music addicted and life lover. Oasis fan since 1995.
# Padre. Marito Innamorato. Sportivo assatanato.
# Presidente Commissione #Sicurezza & #Commercio @ComuneMi #Municipio5 | #Marketing & #Communication Director @ComStrategy https://t.co/nTPv2uqRo4
# opinionista sportiva in tv, ho esperienze di teatro e di vita. Sto studiando per diventare ministro di Dio
# Leggo Bodas de sangre, bevo un gin tonic. C’é una finestra che lascia entrare molta luce. Suona Entre dos aguas. Sogno a sud.
#
#
# Alla costante ricerca di storie da raccontare.
# https://t.co/xhYPWmyVJ0
#
# Alumnus @Unibocconi, @TilburgU and @RagnidiLecco | Investment Banking and outdoors
#
# Romano e romanista, cristiano-peccatore. Nel tempo libero, Medico del Lavoro.
#
# disc jockey - author and producer radio programs - since 1984
# Fìglio di Cesare, Nonno di Cesare
# Insieme su Radio JukeBox dalle 10 alle 15 In tv PrimAntenna Lun ven 7/9 e alle 19 -  Radio JukeBox Tv canale 92 in Piemonte https://t.co/K8rqDlKIso
#
# ...Considero valore tacere in tempo, accorrere a un grido, chiedere permesso prima di sedersi, provare gratitudine senza ricordare di che...
# Mac make up artist
#
# Food Journalist, life storyteller and contributor for Linkiesta Gastronomika, DeAbyDay, Agrodolce
#
#
#
#
# Peak performance leader
# Nobody said it was easy | I want to be Original.
# Bionda senza averne l'aria. https://t.co/u5JjPyw4Pu
# Apprendista papa'
# Law graduate 🎓 European Law PhD 🇪🇺 Love travelling 🌍
# Giornalista
# Docente di recitazione, attore, scrittore, autore, filosofo, giornalista freelance.
# Mamma, moglie, e digital marketing in AIRC. Non sopporto i carciofi, gli allegati alle email, i vocali di Whatsapp. Mi piace osservare le scarpe della gente.
# #pedalognigiorno
#
# Giornalista, copywriter e storyteller. Marito di Serena, papà di Elettra, su Twitter parlo quasi solo di Toro.
# 32 years old, Business Development E-mobility, liberal #sports & #books lover / #socialmedia & #newtech addicted / #emobility
# Altezza 1.75, calvo , labbra sottili. Giornalista, scrittore a tempo perso, amante della musica e  lettura. Parla 4 lingue. Spiritoso,  ironico, autoironico.
#
#
# Amante del calcio e odio le telecronache di Caressa!
# Sono stato scomunicato ma non sono poi così cattivo
# Mi occupo di sistemi informativi e sicurezza informatica da 20 anni.
# Aperte le iscrizioni ai SOGGIORNI PER ANZIANI con assistenza nelle valli bergamasche. vai al sito http://t.co/6yvtIre1A2
# Ingegnere informatico ed esperto in Business Development, Business Processes e... tanta praticità ;)
# Scrivo, rido, leggo, amo molto. Lo Yoga è ciò che più mi rende libera. Web strategist per @titanka_spa
#
# I wish I was like you
# Easily amused
# male, italian, leftwing, teacher, cinephile https://t.co/WoBWweGeHU, insta: @mirkosalvini73
#
#
# Algebra Prof @ Trento University, Italy. Tea lover (aren't the coasters on my profile lovely?)
#
# There's only so much information you can pack into a small space
#
# Le foto nei bagni delle discoteche sono simbolo del declino della civiltà
# “Quello che giova al nemico🇪🇺, nuoce a te🇮🇹, e quello che giova a te nuoce al nemico” (Niccolò Machiavelli)
#
# #facciamorete 🇪🇺 = Blocco istantaneo
# Le armi da guerra non presuppongono coraggio ma buona mira. Jorge Luis Borges
# mi piaccio, mi condivido, mi seguo, mi aggiorno, mi notifico... e nel frattempo lavoro e sorrido :)
#
# Marketing Graduated | Research Analyst on Innovation Insights at Nielsen BASES |
#
# Cogli l'attimo.
#
# Sports and technologies addicted
# Dignità, Dovere, Divertimento.
#
#
# Giornalista del Corriere della Sera. Ho scritto «Portami dove sei nata», Bompiani | https://t.co/9N2QndDDNH | https://t.co/v2Lm7Bxgm1 | 📩 rscorranese@corriere.it
#
#
#
# 39 anni, tutti dalla parte giusta: curva Scirea
# teacher
# 28 anni. Consigliera comunale a Modena e lavoratrice precaria.
# They will not force us
# They will stop degrading us
# They will not control us
# We will be victorious
#
# tra lavoro e week-end mi mantengo giovane, pazza e ... bionda. Per il resto pr e ufficio stampa di 'cose serie', ma su twitter amo commentare i programmi trash!
# 28 | Student | Passionate about photography, jazz music and technology.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Instagram: https://t.co/eMQ39L93mn
#
#
# tecnico sicurity
# La mia fava mi precede
# Studente,Runner,Giocatore incallito di Burraco
#
#
# Scrivo storie. Amo i libri, la montagna.
# Professor of Tax law. Reluctantly Italian.
# #bmth #catslover #videogames #starwars #books #longboard #nursestudent #loveislove
# There's a starman waiting in the sky.              Facoltà di Architettura.
#
# Homo sum, humani nihil a me alienum puto.
#
#
# Cuoca, docente, foodteller. Cucino cose e racconto gente, che essere buoni c’è più gusto. #aifb #apci
# Interista al 100%
# #JusticeForJohnnyDepp
# Pooh, Music, Harry Melling, Dane DeHaan, Merlin, HP, ff Drarry, slash, books ♥ My dream is go to live in Germany (or Spain).
# MD-ORL;ePlayer;Tech-Addicted
# Proud Italian abroad. Trying to make the world a better place to live in.
# ''F di felicita' e fortuna''.
# I'm Alessia, 16, italian! http://t.co/HFOXUwXf3x
#
# senza memoria, per svegliarsi ogni giorno con un discreto umore
# Cambio spesso idea. Anzi no.
# Consultant. Instant capturer. Fond of innovation, art and solidarity. Fan of Milton Erickson. Loving books, food and the world in general.
# Whatever you do in life will be insignificant but it's very important that you do it 'cause...nobody else will.
#
# Giornalista Rai. Oristanese di mamma emiliana residente a Milano. Nomade in odore di stanzialità
# Hi all, I am a young, cheerful and fun solar, do the actor and my dream is to work for the movies to the U.S.A. and I know that one day I will
#
# Nessun profumo vale l'odore di quel fuoco
# Cantautore,Operatore Culturale,nel 2008 montai due casse e un microfono, nacque il LibereVociFestival... in attesa di capire cosa fare da grande...
#
#
# Amo il rossetto rosso, è profondo e sexy... odio l'orologio al polso, mi fa pensare che il tempo scorre sulla mia pelle... Ascolto, Osservo, Scrivo!!!
# ❤AS ROMA  ❤
#
#
# 26 anni; politica, calcio e comunicazione.
# la falsità delle persone fa male ,state attenti a non stuzzicarmi troppo.
# mio figlio unica ragione di vita.lontano da me,ma vicino al mio cuore!
# Stand-up comedian
#
# Volevo scrivere una cosa ma dato che non mi viene il congiuntivo lascio stare..
# Vincenza_Enza_EnzaRita_Vinnie_Cenzina_ una, nessuna, centomila; perché così è, se vi pare 🤓 Pirandello docet
#
# Oltre a piacermi la matematica ho una vita sociale... o quasi! xD
# La pazienza è la virtù dei forti
# no matter what just keeping smile!!
# Marketing and Communication Manager, Theater actor and Improviser, life explorer, free thinker.
# maybe serious maybe fun sometimes more fun sometimes more serious
# Digital Strategist @ BusinessSupport // Runner @ RedsnakesMilano //NaturalBornBlonde // Content is always the king //
# Amante della buona cucina, da cui traggo godimento. Tifoso (pazzo) dell'Inter (pazza), sfegatato per la Mclaren e della F1 in generale, UK & USA addicted!
# ▪️Creative director/designer of Notsnob59 ▫️Atelier in Mantova
# Instagram alessandra_casella_atelier
# ▪️Contact: 📩info@notsnob59.it Shop ⬇️
# freedom = #BTC
# , Psicologa-poetessa. #Lamiagattaèsultavolo è l'ultimo lavoro...
# I swim fast sometimes
# megaminimondo
# UX Writer at @getqonto. In my free time, a stubborn design lover, mountaineer and basketball maniac.
# 28 anni, laureato in scienze politiche all'UNIPV. Malato di sport e televisione.
#
#
#
# Consigliere Regionale della Campania.
# Già Direttore Marketing e Comunicazione Fmts group.
# Direttore e fondatore di Fabula.
# Developer di qualsiasi cosa, spazzino della merda prodotta da altri.. Sono nerd ma non sono figo
#
#
#
# Chitarrista, musicista, cantautore, rocker di professione, in arte Capitan Fede. Per tutti sempre e solo Fede \m/
# You can go your own waaaay (cit. Fleetwood Mac)  ITA 🇮🇹DE 🇩🇪ENG🇬🇧
#
#
#
# Googler, LGBTQ+ activist, dogs lover, trader, boyscout. - Tutto ciò che amo ha dentro il mare (Cit.)
#
#
# IG: pf_92
# ▪️Inter
# ▪️Gym
# ▪️Movies
# ▪️Tech Stuff
#
#
# Cromie Agency - Social Media Management, Foto/Video, Siti Web e Campaign Manager.
# Consigliere Regionale Piemonte Partito Democratico #PresentiperilFuturo
#
# Antifascista, liberale, europeo. Kleine Schritte, langer Weg. 🇮🇹🇪🇺🇩🇪🇬🇧
# soono alla ricerca dell'anima gemella
# 22anni, amante del tennis e del badminton, past presidente Interact di Fasano. GTA V Addicted ❤️ Fasano, Puglia - Italy
#
# racconto le societa' che cambiano. ero nei balcani che si sgretolavano, in sudafrica alla morte di mandela, nella grecia che abbraccia il mediterraneo
#
#
# I like Geeking, Information Technology, Gadgets and Hi-Tech. Hire me, pls ;)
#
# Appassionato di politica e geopolitica, viaggiatore e curioso per natura.
# Composer / Arranger / Orchestrator Insta: #marcomposer
#
#
#
# Vicedirettore #Avanti della domenica. Capo Uff Stampa e Comunicazione @PartSocialista. Prima di tutto Leo. Ho scritto #StorieSegrete 👉🏼 https://t.co/IlaMk9JfW8
# Sindaco di Lanciano, Città Medaglia d'Oro per la Resistenza. Medico, per anni Primario di Diabetologia al Renzetti di Lanciano. Attore di teatro, per passione
# Sono cosí Indie...
# speravo meglio.
#
#
#
# Impiegata di giorno e tortara di notte.
#
# Ingegnere, valutatore immobiliare certificato UNI 11558, sogna di fare il cuoco e di scrivere. Cucina gia', per scrivere si sta attrezzando.
#
#
#
# A volte ho tanto da dire, a volte niente; a volte ho voglia di dirlo, a volte no.
#
#
# Autrice e conduttrice radiofonica, Rossella Panarese è stata l’ideatrice di @radio3scienza e forza motrice ideativa e organizzativa a @radio3tweet
# ... I am what I am: nothing more, nothing less ...
# 10%📸
# 10%🍽
# 10%🛤
# 10%🎦
# 10%🍹
# 10%🎨
# 10%📙
# 10%🚺
# 10%🏋️
# 10%🎶
# =100% this is the summary of my life!
#
# ...e poi boh...faccio cose, vedo gente...beh vabbè adoro!!!
# Insegnante antifascista
# I love daydreaming...make it easier
# Laravel lover, web dev, new amazing framework addicted
#
# jusqu'ici, tout va bien
# Non posso mettere REAL davanti al mio nome,ma posso dire che il mio Real Nome è Stella!
#
#
# Traduttrice freelance  - EN/FR/ES  IT  -  Ideatrice e docente dei corsi *Il traduttore giurato* e *Spagnolo-Spagnoli*  (linguaggio legale)
# Dj deep house, tech house and techno
#
# Mi chiamo Mattia, . Ho Frequentato un Istituto Tecnico Industriale.
# Mi piace molto il mondo dell'informatica. Tifo la #Juventus!
#
# [Ciao Maria, ciao pubblico, ciao studio]
#
#
# 🇮🇹🇧🇷 contabilità, diritto tributario, calcio e politica
#
# Se viene fuori che c'è un Dio, io non credo che sia cattivo, credo che il peggio che si possa dire di lui è che è sostanzialmente un disadattato.
#
# Independent art curator
# Studente di Architettura presso UniCa
# ~ Direttore e Scrittore di #rawiew
# Official page of Andrea Radighieri AKA Böess!!
#
#
# Con la forza della mente!
# Editor and cat lover
#
# Ho fondato e dirigo @ciaolapo e @matermundi con @AlfVann.
# Mi occupo di salute perinatale, di lutto e diritti umani in gravidanza.
# @Ashoka fellow dal 2020
#
# Journalist. Research Associate at Centre for Media Pluralism and Media Freedom  @EUI_CMP @EUI_EU. Writer @editorilaterza
# Rien n'est jamais fini pour toujour.
#
#
# Vivo a Bologna, suono il sax alto, baritono e soprano. Mi interesso a molti generi musicali, ma soprattutto amo la Great Black Music: jazz, funk, r'n'b, reggae.
# Italian freelance Journalist - based in Warsaw - Contributor for RSI
#
# Tweets in IT-EN-PL
#
# Views are mine.
#
# Fidanzato della temerarietà, amante dell'allegria, sposato con la felicità, vedovo della cattiveria!
#
# Giornalista RAI. Tra Roma e la Calabria. In biga (o in lettiga)
#
#
# C'est moi...
# Ciao a tutti, sono Fabio, , vivo a Policoro, una cittadina sul mare in provincia di Matera e tifo Inter. A livello di passione scrivo e canto canzoni.
# In Spagna, mi hanno ribatezzato: Lorena, Gloria, Laura, Lorena Da Ana. Loredana non era poi così difficile
# io sono troppi ex che tutti non ci stanno. Ora sono un pensionato. Poi cambierò con qualcosa di meglio!
# giornalista,giornalaio,giornalaro:la terza vince su tutte...
# Not that kind of girl 🐓
# Siciliana. Curiosa, propositiva e testarda.
# 30enne con tante passioni.
# Il difficile è alzarsi presto ogni mattina, tutto il resto ha soluzioni semplici. ☀
# Dottore in Economia. Consulente del lavoro. Blogger.
# #ForzaNapoliSempre
#
# •`~•` OFFICIAL PROFILE `•~`•
# Intraprendente, combattente, sensibile e mai domo...
# Formatore e Counselor. Ma in realtà vivrei con la tv sempre accesa.
#
#
# Valvola di sfogo.
# Cosa ci fa un bel ragazzo come me in un corpo come questo?
#
# virologo x scelta ,🇮🇹🇮🇹🇮🇹🇨🇭
# Sono tranquilla,sono casinista,Sono libera ma so quello che voglio.Sono un coniglio ,sono un leone.Sono una piuma ,sono un peso massimo.
#  Vado fino in fondo..
#
#
#
# Industrial chemist, living across Milano-Ancona. Techinal Advisor at Arexons S.p.A.- Milanista
# Al di fuori del pensiero comune.
#
# C'é un sentiero che mai bisogna prendere ed è quello della sottomissione.
# Press officer and public relations in music, events and art. Journalist and writer. Born in Naples, resident in Rome. Stumbling often and sleep a little.
# Sfigati si nasce e io lo nacqui, modestamente                                  Esperta in invio cv.
# Per proposte (anche di matrimonio) contattatemi in dm.
#
#
#
# sono orgogliosa della famiglia che ho, non cambierei nulla, sono ironica e autoironica, insomma sono una persona contenta di ciò che ha malgrado tutto.
# Laureato in Scienze della Comunicazione pubblica, sociale e d'impresa presso l'Università di Bologna
#
# Maestro d’ascia su #Lavoro e #PoliticheAttive. Born in Zena. Nipote di naviganti. Ligure, Europeo ora romano! #NoPutin. 3 dosi di Pfizer. #Allviewsmyown
# drummer, guitarrist, bassman..sometimes i play piano.
# Incazzato  con la vecchia politica di SX. Attivo nel M5S
# Jolly Roger 🍖  Hungry Bear 🐻 Blanco Beach Club 💃🏼 Tyler 🍔 Lievito 🍕
#
# fotografo freelance, reporter e matrimonialista
#  http://t.co/hqx0EYv5pf
#
#
# PARRUCCHIERE E BARBER SHOP
#
#
# Il popolo é sovrano
#
#
#
# 22 anni, studio International Management in Bocconi🇮🇹+scambio in Maryland 🇺🇸, mi appassiona il Bene Comune, e non lascio che gli altri decidano per me.Monza
# Giornalista, liberale, liberista, libertario, ciccione, serio(so) quando non faccio il coglione. Chi mi ama mi segue...
#
#
# Politica, Comunicazione, Basket
# studentessa di recitazione, palermo.
# Sono le scelte che fai a renderti ciò che sei.
#
# Habsburger
#
# Blogger seriale, amante della fotografia, nel tempo libero cerco di conquistare il mondo.
# http://t.co/aI16HOo07r
# I like thinking
# 46 anni commerciale 2 figli, 7nipoti. Mi piace Lady Gaga e mi piacciono i fumetti.  A 18 anni pensavo delle cose, ora altre. VORREI UNA SOLUZIONE PER L'ITALIA.
# Pensionato, pagato tutti i contributi , anche straordinari in busta, godo di ottima pensione, nulla da recriminare.
# Laureato in Turismo a Milano, ho vissuto a Londra. Con la passione per libri, arte, viaggi e musica. Frequento Master in Management dei Beni Culturali.
# #noregrets
# co-founder @lecicogne
#
# Amo la mia famiglia, il mio lavoro, i nomadi e il palermo!!! Il mio cuore RosaNero!
#
# Giornalista professionista, socia fondatrice di @bonnepressecom Contributor per @DonnaModerna e @MilanoFinanza
# 🌻Il vento dela vita-Quello che ci resta 💛💛💛
#
# emigrata dalla Puglia per lavoro. Hobby: cinema, lettura, tennis, radio 2...
# Consigliere della Scuola di Cultura Cattolica (@SCC_Bassano), redattore della #vocedeigiovani (@redazione_vdg). Poi basta. Tweet personalissimi.
# Giornalista culturale
# Il Foglio @ilfoglio_it
# and more (e lamponi, i miei preferiti) 🌈🐝
#
#
#
# I'll wait. Forever if I have to.
# Holy cow only 160 letters to say who I am, I don't think I can do this.
#
#
#
#
#
#
# Lavoro come Social Media Manager • Passioni: I miei figli, Argentina, vino |  gabrieleandreozzi@gmail.com • Instagram: @gabrieleandreozzi
# barese ma trapiantato a Roma
# Torno subito, resto ancora un altro pó
#
#
# Segretario regionale Fiom Friuli fino al 2017, tifosissimo dell'Udinese, malato di mountain bike
# Si ritorna solo andando via...!
# 🎈
#
#
# Psicoanalista
#
# motorcycle test.
# ♞♘ Italian Chessplayer 🇮🇹
# ⚽ Za Fó 🔴⚫🔴⚫
# ℹ Instagram: im.misterdani
#
#
#
# Amo la vita, mi piace parlare di tutto e di più e vedo il mondo a colori... soprattutto giallo e rosso
# ho deciso di perdermi nel mondo anche se sprofondo.......!
#
# Hey, don't worry, don't be afraid, ever, because Life is just a ride.
#
#
#
# Lascia correre. Inciamperanno.
#
#
# Direttore presso Bingo.it  - Palermo Kitesurfer presso BKT Kiteboarding hobby : Snow Wake Surf Kite
# Vicentino. Lavora presso la Società del Quartetto di Vicenza. Consigliere comunale della Lista “Da Adesso in Poi”
# Into COMICS, FITNESS & Cristina D'Avena
# Mi sono fatto da solo....... Non sono venuto tanto bene!
#
#
# perfetto gentlemen esperto in compravendite immobiliari in qualità di Agente Immobiliare Professionista economista e risolutore debito italiano
# Preferisco essere abbastanza matto per compiere delle pazzie, piuttosto che abbastanza stupido per credere a delle sciocchezze.Sono solo me stessa...
# Penso dunque trollo.
# L'architettura e' una questione di millimetri (Le Corbusier)
#
#
#
#
# Giornalista, Uff stampa di @Radio3tweet, autrice di Gettoni. Piccole storie di grandi scrittori. Ex #Lacittà, Pagina3, RaiCultura. Gattara, mamma di F e C
# Attore, conduttore radiofonico e televisivo, scrittore. Da qualche anno anche Networker, Leader di livello 7 della piattaforma digitale di oro 24kt GIGOS.
# Arkitetto,interior and yacht designer
#
# Communication & Marketing || Dancer || 24
# Prima gli umani...
# Dott. in Scienze dell'educazione -
# Educatore Professionale Socio Pedagogico
# Pavia, Spezia, Versilia. Una vita lungo la Francigena.
#
#
#
#
#
# E' proprio quando tutti pensano una cosa, che trova spazio una versione differente.
#
# Scrivo perché è la mia passione più grande, leggo perché ho voglia di emozionarmi. Ecco il mio blog:
# Sono una mamma indignata e preoccupata per tutto ciò che sta succedendo. Ma proprio per questo seguo con attenzione politica ed economia .
#
#
# Pasta al pesto enthusiast
#
#
# ho sempre odiato le sorprese, l’ultima poi… (Im)paziente oncologica, e vi assicuro non è piacevole. Vediamo chi vince. 😱😬#fuckcancer 🤞💚🤞💚🤞💚🤞💚
# jòò, ma a me a pellekkia nun m piac!!
# Pistoiese, nato nel '79, grande #tifoso #interista e del #PistoiaBasket, finalmente in #SerieA, appassionato di #tecnologia e #social #network!
#
#
# Mi piace distinguermi dalla massa..
#                         ✌✌
#
# 👨‍👩‍👧‍👧  Dad
# 👨‍💼  Communication advisor
# ⛷  Ski Instructor
# 🏃‍♂️  Runner
#
# Un grammo di comportamento vale 10 chili di parole.....  💖💛💖
# I like the wind.
# I'm a software engineer, interested in technologies and innovation.
# My opinion are only mine and strictly personal.
# ottimista a vita!!
#
#
# Ho bisogno di un caffè
# Avevo paura della solitudine perché sapevo che fosse l'unica che dovunque fossi andata mi avrebbe accompagnata.
#
# papà perennemente spettinato,aderente AC, amo mia moglie quasi quanto la mia Nikon ;b
# cittadino europeo italiano.
# Toccato nel profondo da Charlie Gard 💙
# Che te lo dico a fare...
# Impara ad apprezzare quello che hai, prima di doverlo rimpiangere
# Occidentalista, atlantista libero e liberale. Lettere, Sapere Umanistico e Formazione 📚🏛 Tifoso @acmilan 🔴⚫️
#
#
# LUNGA VITA AGLI ULTRAS
#
#
#
#
# Leggo, dunque sogno. Potenzialmente mi interessa tutto, dopo scelgo. Custode della parola amplissimo. Dimenticavo, sono sommelier. egyzia@gmail.com
# international choreographer/ personal trainer / hip hop model
#
# Appassionato dello Sport più bello del mondo ⚽️
#
# Studente di ingegneria civile. Aut viam inveniam, aut faciam.
#
# Graduated in Economics/Baseball player in Bollate
# Vergine Maria,per favore,fammi diventare un maschio,su,non è cosi difficile,trasformami in un bambino,perché il problema è che io come bambina non vado bene.
# Il miglior modo per uscire da una trappola è di non caderci mai dentro stefano.coccia@libero.it
#
# 28 ~ Travel Art Astronomy ~ BIGGEST SELENA GOMEZ FAN ON EARTH - Buy #Rare 💖
# I love procrastinating and calling it self care
#
#
#
#
# Infermiera di Terapia Intensiva (ICU nurse), ma l'80% delle volte sono io la paziente 💉🤸🏻‍♀️
# niente è più importante dell'amore. Vince sopra ogni cosa. La misura dell'amore? è amare senza misura
# ODIO L'IPOCRISIA PIÙ DI QUALUNQUE ALTRA COSA AL MONDO!!! E LE PSEUDO FEMMINISTE!!!
#
# Software developer, data analist and, first of all, @SSCNapoli supporter
#
# “Non si ama qualcuno perché è perfetto, lo si ama nonostante il fatto che non lo sia.”
#
#
# giornalista, pres. del https://t.co/pbD94mPk0L, dir. di @LineaNewsIT, parlo di #Vicenza #Veneto #sport #calcio #volley #basket #atletica #podcast #radio #cultura #cibo
#
#
# Se ti va aggiungimi su http://t.co/E6hd5eJhxC o seguimi su http://t.co/gLsWdkEM4w
#
#
#
#
#
# Non dare il tuo mille a chi sa contare fino a cento!
# I'm Gabriel, 36, Japanese language and literature lover that truly believes life's in every breath. 百戦錬磨 Degree in Japanese.TQM.Teacher.Twitch:Poruko85
#
# Bertonico (LO), Roma, ora Milano/Lugano.
# Giornalista @StradaReginaRSI, telecronista @ElevenSportsIT. Scuola di giornalismo @wtobagi 2016-18.
# Socio @AC1868.
#
#
#
#
# Laboratorio riparazioni orlologi di tutte le marche dal 1980.  RICAMBI TUTTE LE MARCHE o quasi
#
#
#
#
#
# @UniBocconi @ESCP_bs, 22, sharing news and different perspectives. Interested in finance applied to the real economy and renewable energies.
#
#
# cofounder di coffee bits, appassionato di video-editing e di fotografia. amante della natura e degli animali
#
#
# MEMENTO AUDERE SEMPER
#
# GUARDIA DEL CORPO E ADDETTO ALLA SECURITY
# Gioco con, ma anche di a da in su per tra fra sopra sotto la poesia, mi interrogo su perdite e ritrovamenti di calzini, leggo, scrivo, faccio male i conti.
#
# Allenatore di Calcio UEFA B. Osservatore del Cesena Calcio Laurea in Scienze Politiche nato il 4/3/1975. Emiliano Doc.
#
#
# un diversamente giovane rossonero che ha frequentato s.Siro da quando aveva solo il primo anello
#
# 'Questions of science,science and progress don't speak as loud as my heart.'
#
# Spendo la maggior parte del tempo ad ascoltare e a fare musica... credetemi non è tempo sprecato !!!
#
#
#
#
# London based // human Alexa // mamma prosciutta // my priorities are animals, food and music. 1/3 of @grandkidsitalia ✖️✖️
# There's no way to happiness, happiness is the way.
# Sognando il teatro
# fashion stylist
# Fra la musica ed il video
#
# seguo l’Inter da oltre 58 anni 💙🖤💙🖤💙🖤💙🖤💙🖤presente a Madrid il 22 maggio 2010.
# La libertà economica è la condizione necessaria della libertà politica.
#
#
#
# La vita è una cosa meravigliosa (carpediem)
#
# Alessando Aleotti . Ragione di vita senza ombra di dubbio! Ax non era meglio prima
# Dipendente
#
# guardia giurata
# Grazie, do solo un'occhiata
# Ingegnere elettronico, tecnico competente in acustica ambientale, certificatore energetico, progettazione impianti fotovoltaici, Energy manager.
# 42 anni, modenese, vivo a Brescia e lavoro a Verona, alla #FIM. Due gatte e varie passioni, il sindacato, la filosofia e la psicologia.
#
#
#
#
#
#
# LAUREA IN SCIENZE AGRARIE,ECONOMISTA AGRARIO,PRESIDENTE FUTURIDEA,INNOVAZIONE UTILE SOSTENIBILE
#
# Ristorante pizzeria spcialita tanto amore nei miei piatti Le migliori pizze che si posson assaggiare Con musica e balli
# Studente di ingegneria gestionale appassionato di giornalismo e scrittura ecco il mio blog http://t.co/wLgFjJ8VUJ. Sono in cerca di editore...
#
#
#
#
#
#
# Tutta la vita tra musica, video e installazioni. Amando l'arte e la tecnologia.
#
#
#
#
#
#
# Un italiano sempre in fuga da un paese in panne ✈️
# Voglio un futuro perché tutto il mio passato è in fiamme 🔥
# Tutto e' iniziato alle elementari con la poesia L'inviato speciale.
#
#
# ... In informatica, come nella vita, non si finisce mai di imparare!
#
# a cosa serve che scrivo su di me?se mi conosci mi segui.cook,live,love Romagna ❤
# gay... ciccione... single... stronzo...
#
#
# Work in a FinTech company,beauty and make-up addicted,mi perdo dentro un sacchetto di caramelle gommose e credo ancora nelle favole.
#
# Administrative Assistant
#
# ◽Sono molto pєggio di quєllo chє si possa pensarє.
# ◽La gentilezza fa male.
#
# 🔺No Chat
# 🔺No Profili Porno/Fake
# 🔺No Ipocriti
#
# 01031994//// ciao a tutte sono julia ed ho un canale YouTube che vorrei far crescere (makeupjulia) se non lo conoscete dateci un occhiata ❤️❤️
# Mah
# giulietto grosso
# she/her
# si lavora x vivere e non vivere x lavorare!!!!!! già lavorare sarebbe vivere
# Controllore del Traffico Aereo.
# Appassionato di cucina e di musica.
# Tifoso della Roma ma senza paraocchi.
#
# Spesso risulto simpatico, altre volte NO.......
#
# Amante della #natura e dell’ #ambiente, appassionato di #orticoltura e #tecnologia, professionista della #SupplyChain e tecnico #agroalimentare 🚜🍀🌹🐞🐝🐌🧤
#
#
# consulente finanziario
# Purtroppo non ho la verità in tasca
# Enaip vimercate
# Mi chiamo Giulia  e sono una ragazza sportiva❤ Amo la palestra e amo tenermi in forma ❤
# 23 anni, laureanda in media e istituzioni.
# Ciao a Tutti Mi chiamo Alessandro Gervasoni  , collaboro come speaker in una radio locale in Valle Brembana ( Bg) , tesserato Pd .
# Atleta, scrittore, web designer. Mi piace guardare le cose da un lato diverso, dal mio.
# Ho scritto un romanzo: The Timeless Warrior
#
#
# Giornalista. Assiduo narratore di storie, con la penna, la parola e la chitarra
#
#
# Hi, my name's Clelia.. I'm italian .. I love photos
#
# Follow me!
#
#
#
# Rome. Senior Consultant @ EY - Anti-Fraud, Anti-Corruption area - LinkedIn: https://t.co/QilIeSNxCi…
#
# yoooooo amo TWITTER,il CALCIO, tifo JUVEEE ed ETTORE CALABRESE è un pirlaaaaaaaaaa.... VIVA LE VACCHE SVIZZERE
# Visita il mio blog https://t.co/7b7JO0P5HY e la mia pagina facebook Allergico all'allergia
#
# Mi dichiaro giornalista politico. In parlamento dal 1985. Autore di Rai3 & altro. Irregolare e deviante, chance ou malchance. Opinioni personali, se mi va
#
# Marketing Lead at tech startup, tweeting mostly about news, politics, psychology, data, etc. Atypical Italian: I have cappuccino in the afternoon.
# Il bianco e il nero sono colori che contengono tutto, Sono di una bellezza assoluta. È l'accordo perfetto. Sono juventino dal 1 novembre 1897
#
#
# Giornalista pubblicista, laureato in Scienze Statistiche e Ingegneria informatica. Ambasciatore del #PoveroMe nel mondo
#
# Serena di nome e di fatto
#
# 🍺 Tuttofare presso un’azienda di impianti alla spina 📷 Fotografo per passione 🧢 Allenatore Uefa C 💜 Fiorentina
#
# Interista e... ho detto tutto. Lia, Andrea e Martina, la mia vita. Il basket la mia passione da 45 anni.
# 🇮🇹🇬🇧🇫🇷🇪🇸🇨🇳 speaker. Business consultant 👨‍💻
#
# Videomaker pensionato, calciatore mai sbocciato, amante del vitello tonnato.
#
# Bresciano-siciliano nell'Urbe | Laureato in Relazioni internazionali (LM-52)
#
# (...) Uno non pratico, che non ha il polso di un matematico...
#
# 👩🏻Giorgia
# 🎂27
# ❤️Libri, fotografia e animali
# 🔸Mi diletto a parlare di libri e creare contenuti su Instagram
# Barack Obama, Don Winslow, Michael Jordan, Kobe Bryant, Bruce Springsteen, Sandro Pertini , Paolo Pulici.
#
#
#
#
#
# Teacher | Vocalist | Voiceactress | Hyperdestinia Vocalist | @ParsifalGaming 's Wife and Tommaso’s Mum ❤️ Alle stelle che ascoltano, e ai sogni che si avverano✨
#
#
#
#
# I was a full professor at the University of Perugia and the barley breeder at ICARDA, Aleppo Syria until 2006. Currently I am an international consultant
#
#
#
#
#
# consulente amministrativa e pensionata
#
#
#
# Cardiologo dedito alla cura delle persone. Sono appassionato di cinema e curioso di sociologia, tecnologia, web e social. Ho fondato Omnibus Salute.
#
# 23 anni,studentessa di Scienze politiche alla @LuissGiudoCarli. Scrivere è la mia vita, la musica riesce sempre a salvarmi. Sogno molto,dormo poco.
#
# Roma/RC
# Online English and professional tutor. #IamRemarkable facilitator.
#
#
#
# ✨A piccoli passi si raggiungono grandi traguardi✨. Forza Milan!!!!⚽️
#
# Volleyball player, lover & blogger. Web Marketing Specialist at @Marketing_Info
# “La normalità era solo quello che la mia volontà, il mio impegno e la mia parola avrebbero accettato che fosse, e per quel motivo sarebbe stata sempre con me''
# Incurable optimist 🙃
#
#
#
# FrancoGiuseppeCortesi.55 anni, laurea politica internazionale Alfieri FI 87  quadro alto da 96, giornalista da 90. Licenziato ingiustamente da 27/11/2012
# Sono mamma, nonna, conciliare tutto non è semplice, mi sto attrezzando per compiere il miracolo
# Alla perenne ricerca di una collocazione.
# Sono Italiano, mi piacciono i Dire Straits e sono leghista
# ciao  a  tutti.io vivo ad Ancona e  cerco  nuove  amicizie.ciao
#
# Preferisco ridere.....I prefer to laugh
#
# Il sole stesso non vede se le nuvole non si diradano.
#
# E se ti succede ancora...di guardare in faccia il mare...giri in fretta gli occhi e il cuore...che hai ben altro a cui pensare!
# Succede solo che sono felice  fino all’ultimo profondo angolino del cuore.
# (P. Neruda)
#
#
#
# notturna
# pubblicitario-scrivo-dipingo-disegno e a volte m'incazzo
# Seriamente. Che altro ci può capitare.
#
#
#
# Tuttobolognaweb, Gazzetta, Gazzanet, Quotidiano Nazionale, Radio 1909. Bolognese doc. Vi avviso: sono tutto tranne che perfetto.
#
#
#
#
#
# Funziona solo se stiamo insieme!!
#
#
#
#
#
# Sono di Milano Italia, mi piace confrontarmi sempre con educazione
# ☮
# 𝑵𝒐𝒍𝒊𝒕𝒆 𝒕𝒆 𝒃𝒂𝒔𝒕𝒂𝒓𝒅𝒆𝒔 𝒄𝒂𝒓𝒃𝒐𝒓𝒖𝒏𝒅𝒐𝒓𝒖𝒎.
#
#
#
#
#
#
#
#
#
#
#
# A volte penso addirittura che Napoli possa essere ancora l'ultima speranza  che resta alla razza umana
#
#
# Adolescente,amante dello sport,Calcio e Tennis,Juventino.
# Scrivo per arrivare al cuore delle persone, per scoprire le loro emozioni, le loro sensazioni più profonde e segrete.❤
# Bisogna ridere perchè fa bene.
# La superficialità mi manda in bestia.DI SINISTRA SEMPRE.Beatles,gatti ,Natura, le mie passioni.
# The Big Bang Theory addicted
#
#
#
#
# Bionda onoraria, aspirante dittatore dopo aver visto un documentario netflix. Scorpione, ascendente Debbie Addams. IG: magno__gram
#
#
# Per evitare inutili discussioni...
# Non interagite con me se siete:
# Grillini
# PiDini
# Europeisti
# Facciamorete
# evitateme!
# Vi ringrazio
# #tech
#
#
# Romano, e fiero di essere italiano. Studente di Giurisprudenza.
#
# FCO di Lodovica Comello, Francesca nella serie Disney Violetta  #UNIVERSO #IOnlyWantToBeWithYou http://t.co/mbNJDKZFRK
#
# io qua tu là io amo la libertà. Non so più a cosa appartengo, ma non affondo
# sono sicuro che non ci capirò niente...
#
#
#
# aspetta a dimenticare le strie incantate di maghi e di fate la vita non è come credi è peno d'insidie dolori e tranelli
# distugge in un attimo
# I SOGNI PIÙ BELLI
#
#
#
#
#
# Medical Doctor, in the (little) spare time: Broadway, music, theatre (all kind of theatre, all kind of music), books, travels addicted. Be curious. #HDM
#
#
# #ProudOfLouis #ProudOfHarry 🔪🌹
#
# 😘
# tifoso del napoli
# Così parlò Bellavista di Luciano De Crescenzo: libro, film, tutti conoscono le mie battute. Nasco come personaggio di Totò, travestito da filosofo, uomo d'amore
#
#
#
#
#
# Are a natural bodybuilding Calabra Italy---Geometra Presso TM prefabbricati
# https://t.co/ipvMyJ78px
# http://t.co/gjqkplRjMu
#
#
#
# Dicono che non potrei
# Dicono che ho il cuore a metà-
#
# ITALIANO PER DISGRAZIA. Non sopporto i falsi buonisti e chi ancora crede ai politici che ci violentano da sempre. Amichevole e spontaneo.
# consulente commerciale presso Vithagroup
#
#
#
#
#
#
# Fatti forza è la vita sai che ti sfida.
#
#
# I'm Lord of all darkness
# I'm Queen of the night
# cantare
#
# 💯
#
# L'Occidente è un fiore cresciuto una sola volta nella storia. E adesso senza pensarci avete deciso di schiacciarlo.
#
#
# Giornalista web. Ho scritto per @Limesonline e @Mark_Up_, leggo libri per @Mondadori. Ho una newsletter, si chiama “Dentro gli androni”. Cuore nerazzurro
# 21 anni, Calabria. Innamorato del giornalismo sportivo. Malato di calcio, malato della @Juventus ⚪⚫ #finoallafine #VR46 #Ferrari
#
#
#
#
#
# Commercialista, giornalista pubblicista, amo la vita
#
#
#
# Ti ho mai detto qual'è la definizione di follia?
# Giornalista (L'Espresso - Ohga)
# Curioso e battagliero. Mi piace dar voce a chi non può parlare per sé.
# Attivista Lgbt+, a Milano ma con il cuore a Roma
#
#
#
#
# Mille facezie e motti di spirito.
#
# Non mi chiamo Duccio | she/her
#
# ☉ ♋ ☾ ♓ ↑ ♐
# S’i’ fosse Carlo come sono e fui, torrei le donne giovani e leggiadre e vecchie e laide lasserei altrui.
#
# Professore ordinario di Diritto costituzionale - Università del Molise - opinioni personali
# #Costituzione #Diritto #Democrazia #Diritti #Politica
#
#
# Di tutto un po'! Opinione personale sui prodotti testati. https://t.co/q4htqQN9yk
# Gemma Edizioni
# #nVITE #n1Vite #SelfieDiNoi #FavoleDiCioccolata
# Progetti : #Legga33 #Babel  @gemmaedizioni
# https://t.co/4m2LSdQBXV…
#
# gemmaedizion
#
# #giornalista
#
# jackie
#
#
# • faccio schifo ma con parsimonia • 🏳️‍🌈 he/him
# schizzosimona2014@libero.it
#
# Intermediario assicurativo e finanziario. contatti:assimancini@gmail.com
#
# @ffrittelline
#
#
# 📍Milano 🇮🇹 👷🏻‍♂️Muratore @edilcapsrl  🏳️‍🌈 LGBT+  🌈Tra i fondatori @isentinelli  😻Papà di 2 Gatti  🎒Viaggio 📸 Scatto 📱
# ☀️Sono una ragazza a cui piace la natura, gli animali, la musica e la fotografia!
#
# https://t.co/7mQknKE5Vt
#
#
#
# genitore amante dell'Africa ed attento osservatore delle ingiustizie sociali globali, amante dell’ambiente e veterinario per passione
# Milanista❤️🖤
# Ottimista😉
# Cibo dipendente🍔🥩🍝🍗🍕🍟🍰
# Degustatore di Vino🍷e Birra🍺
# Vascomane😎
#
# DIO, PATRIA, FAMIGLIA.
#
# “ C’è una strada che, se la scegli, ti conduce in tutte le direzioni: il rispetto. ”
# Antonio Cuomo
#
#
#
#
#
#
#
# @ncis forever
#
# 🇷🇺
#
# Hey Twitterosi!Sento Odore Di...Follow Me!*-*Seguitemi E Vi Seguo!Ricambio A Tutti Quanti!Vi Voglio In Tanti!Io Adesso Sto a 140...Vorrei Arrivare A 240...^-^
#
# Capire le persone
# Crotone
# 27-05-00
#
# Chiamatemi Esp| 15.| vorrei scrivere qualcosa di figo,ma non mi viene niente.
# ?
# Irreversibilmente ottimista, ai limiti dell'ingenuità. Sorrido. Leggo tutto il giorno, per lavoro e per me. Aspetto un'estate migliore e propizia.
#
# Sognatrice sconclusionata perennemente e disperatamente alla ricerca della vita.
#
# Sessuologa. Psicologa. Scrittrice. ♥️ @lastampa https://t.co/xBhqBOkc9o
#
#
#
#
#
#
#
#
# Sono ottimista. .ma preoccupato. ...non vorrei che Renzi si stancasse troppo di combattere contro le teste di cazzo..
# Pensare Oltre
# ❤HEYY GUYS❤ FOLLOW ME ON MUSICA.ly & Instagram :@deeedux   thanks Jacob and Brandon for follow me I love yaa🌹
#
# Viaggiare è il mio lavoro e la mia vita. Concreta e spirituale. Ho la lacrima facile ma mai quanto il vaffanculo.
#
#
# Tante aspettative e sogni puntualmente disattesi~ Sempre sull'orlo di un crollo emotivo~ Jeremy Strong & Taylor Swift Stan Account~ she/her🌈
#
#
#
#
# Non problemi di individuazione nè di affermazione. Odio la massificazione e il gregge. Il mio cervello è solo nella mia disponibilità.
#
#
#
# ,da poco, dopo 7 anni di convivenza mi sono lasciato appassionato  di motori,sono romano,vivo a Roma ,precisamente,vicino al litorale ciao a tutti
#
#
#
#
#
#
#
#
# Lotto e non mollo
#
#
#
# Boh
#
#
#
# Non esco mai senza:
# cinismo,
# rossetto rosso,
# appetito.
#
# vivo a Trieste di Fuerteventura ho  frequentato il conservatore G.Tartini.                         ❤️ sposata
#
#
#
# "la mente è come il paracadute. Funziona solo quando è aperta" A. Einstein
#
#
# Ama tutti, credi a pochi e non far del male a nessuno. W.S.
#
# Interessato a scambiare idee, punti di vista, opinioni ed esperienze con chiunque sappia esprimersi civilmente.
# .
#
# Antifascista e anti renziano.
#
#
#
#  e lavoro da 32 alle Poste Italiane spa
#
#
#
# L’autoironia.
# Tifoso del Milan dalla nascita
# Avvocato curioso che non sopporta banalità. Ogni idea merita rispetto. Nessuna deve essere insultata. E prima di tutto e di tutti, l’Italia🇮🇹#LaReteSiamoNoi
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Studentessa, scrittrice, atipica.
#
#
#
#
# Mamma ,nonna,orgogliosa di esserlo.loro sono la mia vita ,i miei figli e nipoti.ho  la carica e la voglia di vivere.mi piace la tv,i film la natura gli animali
#
# ✍🏻 Giornalista | 📍 #Napoli | Former @CalcioNapoli24 | Oggi @fantacalcio e @serieanews_com | Spesso ripeto cose che ho già detto, ma non lo faccio di proposito
# Musica Calcio Club della Serie A TIM Informazione Governo & Istituzioni Politica
#
#
#
# Piedi nelle Air,testa sulla luna!❣
#
#
#
#
#
#
#
# MI  PIACCIONO LE BIMBE OVVERO DONNE IN LINGERIE BACIONI DOLCISSIME BIMBE
# Claudia/18 anni / Como 💕
#
#
# Non è  orfano colui che perde i genitori,ma coloro che perdono la speranza. La speranza è già  domani.
#
# PhD. Economics
#
# Se adottiamo un punto di vista corretto, possiamo tenere sotto controllo vaste distanze per quanto limitata sia la nostra persona
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# settantenne giustizialista obeso, laico, euroscettico, no-antifa, omofobo, gattaro perso, grande viaggiatore, destrorso, laziale, ora alla canna del gas...
#
#
#
#
#
#
# Clinical Case Coordinator @Medendi2
# MBA @mbaCDIITALIA
# PhD Cancer Biology @unigenews
# Bio-Mol @unito
# Contributor @repubblica
# TO-OXF-MAD-GVA 🇮🇹🇨🇭🇪🇺
#
#
#
#
#
#
#
#
# Romano doc.
#
#
#
#
#
#
# Illusa, disillusa, delusa.
# Ingegnere Musica Food & Lifestyle Politica Sport Tecnologia e Scienza Arte e Cultura
# Nato a Me1946.Per lavoro a Mi. Sposato 3Figli.Oggi Pensionato .Nonno 4 Nipoti.
#
#
#
# Amore per la natura
#
#
#
#
#
#
# Per un cazzo di raffreddore, due anni di merda. (cit. Quaerens me@Enrico26659481)
#
#
# casalinga ma mi guardo sempre attorno
# 18, Bologna.
# AC MILAN - Ballerino alla radio
# Il fine non giustifica mai i mezzi
#
# 🏴‍☠️🇺🇦🇹🇼
# Si sta' come d'autunno
# sugli alberi, le foglie
# Gioia
#
# Giornalista, scrittore, consulente parlamentare, perito giudiziario, un paio di incarichi universitari: e mi sono pure divertito. https://t.co/ExjYHyTvId
# Sardo, classe '86. Cuoco per vocazione e studente di scienze politiche per passione.
# Adoro il cibo, la storia dell'Antica Roma, l'astronomia e la Juventus.
#
# Non sono speciale la mia famiglia lo è !
#
# Lettrice illeggibile, viaggiatrice appena posso, un pochino sognatrice
#
# Sono un ex ristoratore in pensione
#
# Persona normale niente di eccezionale però VIVA
# trasparenza
#
# The man Surname Bimbo
# Curiosa e generosa
# Dicono che chi semina bene raccoglie i frutti .
# Spesso gli altri raccolgono e tu zappi.
# La gatta sul tetto che scivola no omofobi ne razzisti
# Lawyer, amateur MtG player, wannabe bassist, creator of bad quizzes on Sporcle; He/Him
# PRIMA GLI ITALIANI. PATRIOTA. ITALEXIT. NO EURO. NO IUS SOLI. NO ISLAM.🇮🇹🇮🇹🇮🇹🏴󠁧󠁢󠁥󠁮󠁧󠁿🏴󠁧󠁢󠁥󠁮󠁧󠁿🏴󠁧󠁢󠁥󠁮󠁧󠁿
# Madre e nonna. Professoressa di Matematica , #Sorcina grande Renatoo
#
# Simpatia
#
# Niente perché non mi sento speciale.
# Lo penso, lo scrivo:
# io dico la mia, tu dici la tua e viviamo tutti felici e contenti.
#
# leggo tutto quello che mi capita a tiro e cerco di pensare con la mia testa.
#
# Scledense a Venezia, studente di Storia Contemporanea a @CaFoscari, coordinatore @ugs_nordest e segreteria nazionale @ugs_ufficiale. Comunista
#
# MD, Ph.d. Kinky worldwide psychologist/mentalist. Mil Historian Nap Age, warfare analyst. Very happy married with wonderful Beatrice now mom to 2twins
# Marta
#
#
#
# Sugar
#
#
#
# Neve d'Estate 🌞🌨️ ➖Irpino 🐺➖U. S. Avellino 1912 ⬜🟩➖
# «Si descriva in due parole»
# «Pigro...».
#
#
#
# Ragazzo di 17 anni, pianista e chitarrista
#
# La  curiosità
#
# la sincerità
#
#
# amore estremo e ultraviolenza, del resto tutto ha senso nella testa di chi lo pensa
# Il fascismo si cura leggendo. Il razzismo si cura viaggiando.
# Figlio del Vesuvio!!!
#
#
#
#
#
# io
#
# Non è come sembra, posso spiegarvi tutto
#
# in love with art and cinema
#
#
#
# ridatemi la sinistra...
#
# QUANDO SULLA SCHIENA HAI CICATRICI, È LÌ CHE CI ATTACCHI LE ALI. 💛💛💛
#
#
# nonno
# ..Ama, ama follemente, ama più che puoi e se ti dicono che è peccato, ama il tuo peccato e sarai innocente ❤️
#  🍀🍀🍀😂😂😂❤️🌈
# non entra tutto il cognome nel nome utente lol
# se non avessi una bandiera non saprei che vento tira @acffiorentina | account sospeso @xnaaalj | INFJ-T |she/her
#
#
#
# Mare
#
#
# Francoforte-Roma -Medellín .🇮🇹🇳🇱🇮🇱🇨🇴🇺🇸🇨🇺 A destra dalla nascita ,sono a volte  Rudy  a volte Valentino .
#
# Solarità
# Lottare e vincere 🎗💚.
# Capire il senso della vita e metterlo avanti ad ogni cosa.
# Trovare l'amore e realizzare di avere davvero TUTTO ❤.
#
#
#
# Sono un mercenario ouihgyddre
#
#
#
# 𝘕𝘢𝘳𝘤𝘰𝘭𝘦𝘱𝘴𝘺 𝘨𝘰𝘵 𝘮𝘦 𝘧𝘦𝘦𝘭𝘪𝘯𝘨 𝘴𝘵𝘢𝘨𝘦 𝘧𝘳𝘪𝘨𝘩𝘵
#
# ✧˚ ༘ ⋆｡♡˚
# She/her
# ⋆｡ﾟ☁︎｡⋆｡ ﾟ☾ ﾟ｡⋆
# Mercury dominant
