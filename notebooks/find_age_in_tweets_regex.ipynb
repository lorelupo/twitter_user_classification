# %% [markdown]
# ## Regex pattern to match declarations of age or year or birth

# %%
import re
import random
import pandas as pd

# %%
AGE_CHAR = [
    'novantanove',
    'novantotto',
    'novantasette',
    'novantasei',
    'novantacinque',
    'novantaquattro',
    'novantatre',
    'novantadue',
    'novantuno',
    'novanta',
    'ottantanove',
    'ottantotto',
    'ottantasette',
    'ottantasei',
    'ottantacinque',
    'ottantaquattro',
    'ottantatre',
    'ottantadue',
    'ottantuno',
    'ottanta',
    'settantanove',
    'settantotto',
    'settantasette',
    'settantasei',
    'settantacinque',
    'settantaquattro',
    'settantatre',
    'settantadue',
    'settantuno',
    'settanta',
    'sessantanove',
    'sessantotto',
    'sessantasette',
    'sessantasei',
    'sessantacinque',
    'sessantaquattro',
    'sessantatre',
    'sessantadue',
    'sessantuno',
    'sessanta',
    'cinquantanove',
    'cinquantotto',
    'cinquantasette',
    'cinquantasei',
    'cinquantacinque',
    'cinquantaquattro',
    'cinquantatre',
    'cinquantadue',
    'cinquantuno',
    'cinquanta',
    'quarantanove',
    'quarantotto',
    'quarantasette',
    'quarantasei',
    'quarantacinque',
    'quarantaquattro',
    'quarantatre',
    'quarantadue',
    'quarantuno',
    'quaranta',
    'trentanove',
    'trentotto',
    'trentasette',
    'trentasei',
    'trentacinque',
    'trentaquattro',
    'trentatre',
    'trentadue',
    'trentuno',
    'trenta',
    'ventinove',
    'ventotto',
    'ventisette',
    'ventisei',
    'venticinque',
    'ventiquattro',
    'ventitre',
    'ventidue',
    'ventuno',
    'venti',
    'diciannove',
    'diciotto',
    'diciassette',
    'sedici',
    'quindici',
    'quattordici',
    'tredici'
 ]

# remove last letter of each years_in_words entry, in order to match both
# the noun ("ventiquattro") and the adjective ("ventiquattrenne")
AGE_CHAR_SUFFIX_LONG = [year[:-1] for year in AGE_CHAR]

# keep only the shortest form as a first filter
AGE_CHAR_SUFFIX_SHORT = [
    "tredic",
    "quattordic",
    "quindic",
    "sedic",
    "diciasset",
    "diciott",
    "diciannov",
    "vent",
    "trent",
    "quarant",
    "cinquant",
    "sessant",
    "settant",
    "ottant",
    "novant",
]

AGE_DIGIT = list(range(99,12,-1))

# List of regex patterns for matching Twitter posts mentioning the age of the user
# The patterns are built using the age expressed in digits (e.g. "22" for 22)
AGE_DIGIT_PATTERNS = [
    # Matches phrases like "ho compiuto 22 anni" (I just turned 22)
    # but not "quando ho compiuto 22 anni" (when I turned 22)
    # nor "ho compiuto 22 anni di/de" (I have 22 years of)
    r"(?<!quando\s)(?<!quando)ho\s*compiuto\s*(\d{2})\s*anni(?! de)(?! di)(?!de)(?!di)(?! in più)(?! in meno)",
    r"\bcompio\s*(\d{2})\s*anni(?! de)(?! di)(?!de)(?!di)",
    # Matches phrases like "ho 22 anni" (I am 22 years old)
    # but not "da quando/non ho 22 anni" (since I am / I am not 22 years old)
    # nor "ho 22 anni di/de" (I have 22 years of)
    # nor "se ho 22 anni" (if I am 22 years old)
    r"(?<!quando\s)(?<!quando)(?<!non\s)(?<!non)(?<!se\s)(?<!se)ho\s*(\d{2})\s*anni(?! de)(?!de)(?! di)(?!di)(?! in più)(?! in meno)",
    # Matches phrases like "faccio 22 anni" (I am turning 22 years old)
    # but not "faccio 22 anni di/de" (I have 22 years of)
    r"\bfaccio\s*(\d{2})\s*anni(?! de)(?! di)(?!de)(?!di)",
    # Matches phrases like "spengo 22 candeline" (I am blowing 22 candles)
    r"\bspengo\s*(\d{2})\s*candeline",
    # Matches phrases like "il mio 22^ compleanno" (my 22nd birthday)
    r"il\s*mio\s*(\d{2})\^\s*comple(?:anno)?",
    # Matches phrases like "sono un 22enne" (I am a 22-year-old...)
    r"\bsono\s*una?\s*(\d{2})\s*enne",
    # Matches phrases like "i miei 22 anni" (my 22 years)
    # r"\bmiei\s*(\d{2})\s*anni",
]

def return_full_age_char_pattern(age_char):
    """
    Returns a list of regex patterns for matching Twitter posts mentioning the age of the user.
    The patterns are built using the age_char parameter, which is a string containing the
    Italian word for the age of the user (e.g. "ventidue" for 22).
    """
    age_char_patterns = [
            # Matches phrases like "ho compiuto ventidue anni" (I just turned twenty-two)
            # but not "quando ho compiuto ventidue anni" (when I turned twenty-two)
            # nor "ho compiuto ventidue anni di/de" (I have twenty-two years of)
            r"(?<!quando\s)(?<!quando)ho\s*compiuto\s*({}).*\s*anni(?! de)(?!de)(?! di)(?!di)(?! in più)(?! in meno)".format(age_char),
            r"\bcompio\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)".format(age_char),
            # Matches phrases like "ho ventidue anni" (I am twenty-two years old),
            # but not "a quando/non ho ventidue anni" (since I am / I am not twenty-two years old)
            # nor "ho ventidue anni di/de" (I have twenty-two years of)
            # nor "se ho ventidue anni" (if I am twenty-two years old)
            r"(?<!quando\s)(?<!quando)(?<!non\s)(?<!non)(?<!se\s)(?<!se)ho\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)(?! in più)(?! in meno)".format(age_char),
            # Matches phrases like "faccio ventidue anni" (I am turning twenty-two years old)
            r"\bfaccio\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)".format(age_char),
            # Matches phrases like "spengo ventidue candeline" (I am blowing twenty-two candles)
            r"\bspengo\s*({})\s*candeline".format(age_char),
            # Matches phrases like "mio ventiduesimo comple/compleanno" (my twenty-second birthday)
            r"il\s*mio\s*{}e?simo\s*comple(?:anno)?".format(age_char),
            # Matches phrases like "sono un ventiduenne" (I am twenty-two-years-old...)
            r"\bsono\s*una?\s*({})\s*e?nne".format(age_char),
            # Matches phrases like "i miei ventidue anni" (my twenty-two years)
            # r"\bmiei\s*({}).*\s*anni".format(age_char),
        ]
    return age_char_patterns

def tweet_user_age(tweet):
    """
    Returns the age of the user who posted the tweet, if the tweet contains a mention of the user's age.
    TODO: the age returned by this function should be compared with the creation date of the tweet.
    """
    if len(tweet) > 0:
        # check if the tweet contains a double digit number, but not in a quoted text
        if re.search(r"\d{2}", tweet):
            if not re.search(r"\".*\d{2}.*\"", tweet) \
                and not re.search(r"\“.*\d{2}.*\”", tweet) \
                and not re.search(r"\«.*\d{2}.*\»", tweet):
                # search for age patterns
                for i, pattern in enumerate(AGE_DIGIT_PATTERNS):
                    matches = re.findall(pattern, tweet, flags=re.IGNORECASE)
                    if matches:
                        return {"tweet": tweet, "age": int(matches[0]), "regex_idx": i}

        # check if the tweet contains an age expressed in characters
        if re.search(r"{}".format("|".join(AGE_CHAR_SUFFIX_SHORT)), tweet, flags=re.IGNORECASE):
            # check what age is expressed in the tweet and retrieve its index
            matching_age_char = re.findall(r"{}".format("|".join(AGE_CHAR_SUFFIX_LONG)), tweet, flags=re.IGNORECASE)[0].lower()
            matching_age_char_index = AGE_CHAR_SUFFIX_LONG.index(matching_age_char)
            # check if the age is not in a quoted text
            if not re.search(r"\".*{}.*\"".format(matching_age_char), tweet, flags=re.IGNORECASE) \
                and not re.search(r"\“.*{}.*\”".format(matching_age_char), tweet, flags=re.IGNORECASE) \
                and not re.search(r"\«.*{}.*\»".format(matching_age_char), tweet, flags=re.IGNORECASE):
                # check if also the full form of the age is present in the tweet
                if re.search(r"{}".format(AGE_CHAR[matching_age_char_index]), tweet, flags=re.IGNORECASE):
                    patterns = return_full_age_char_pattern(AGE_CHAR[matching_age_char_index])
                else:
                    patterns = return_full_age_char_pattern(AGE_CHAR_SUFFIX_LONG[matching_age_char_index])
                # search for age statements and retrieve age
                for i, pattern in enumerate(patterns):
                    matches = re.findall(pattern, tweet, flags=re.IGNORECASE)
                    if matches:
                        return {"tweet": tweet, "age": int(AGE_DIGIT[matching_age_char_index]), "regex_idx": i}

    return {"tweet": tweet, "age": None, "regex_idx": None}

# Example tweets
tweets_should_match = [
    "ho compiuto 50 anni e non mi importa più niente.",
    "Ieri ho compiuto 60 anni e mi sento freschissimo.",
    "Tra un mese compio 25 anni e non vedo l'ora.",
    "Ormai ho 30 anni, damn...",
    "Finalmente faccio 18 anni!!!",
    "Cosa vuoi che ne sappia di vecchiaia, sono una 28enne...",
    "Spengo 40 candeline domani, che emozione.",
    "Grande fiesta per il mio 22^ comple.",
    "Grande fiesta per il mio 22^ compleanno.",
    "--------------------------------------------------------",
    "Ieri ho compiuto sessanta anni e mi sento freschissimo.",
    "Ieri ho compiuto sessant'anni e mi sento freschissimo.",
    "Tra un mese compio venticinque anni e non vedo l'ora.",
    "Ormai ho trent'anni, damn...",
    "Finalmente faccio diciotto anni!!!",
    "Cosa vuoi che ne sappia di vecchiaia, sono una ventottenne...",
    "Spengo quaranta candeline domani, che emozione.",
    "Grande fiesta per il mio ventiduesimo comple.",
    "Grande fiesta per il mio trentunesimo comple.",
    'Mi sento in diritto di dirlo in quanto sono un ventiduenne.',
    "HO VENTICINQUE ANNI gioventù",
]

tweets_should_not_match = [
    "Ma che ne so della vita se ho 22 anni?",
    "Quando ho 60 anni vado a vivere alle bahamas.",
    "Lo sapro' meglio io che ho 30 anni in più di te.",
    '@officialsslazio me faccio 30 anni de galera ma te vengo ammazza co le mani mie VERME BAVOSO',
    'Io ho 42 anni di contributi versati, ma "solo" 61 anni di età!',
    'Per il lavoro ho 30 anni di industria sulle spalle.',
    'Le nuove estetiste cinesi sotto casa mi hanno chiesto se ho 24 anni.',
    'Jovanotti: «Ho 50 anni, per me  è un’età assurda»',
    'cara non ho 13 anni, e vedo che vi viene molto difficile tenere una discussione in maniera pacata',
    '“Ho 17 anni e faccio sesso a pagamento: voglio avere tanti soldi e fare shopping”… https://t.co/9NbPpmqRnG',
    "Da quando ho compiuto 50 anni non mi importa più niente.",
    "Guarda sinceramente vedere un ragazzo ridursi a fare questi commenti da 50enne scapola è triste.",
    'l signor "meno male che ho 49 anni".... Lo schifo.',
    "ricordo ancora i miei 22 anni",
    "Porto i miei 77 anni come un giovincello.",
    "Praticamente ho 80 anni", # impossible to detect without semantinc analysis
    "--------------------------------------------------------",
    "Ma che ne so della vita se ho ventidue anni?",
    "Quando ho sessant'anni vado a vivere alle bahamas.",
    "Lo sapro' meglio io che ho trent'anni in più di te.",
    "@beatriceletre Fisico da ventenne.\nStai un bijoux🌹😘",
    "Da quando ho cinquant'anni non mi importa più niente.",
    'Perché è il mio compleanno e al mio diciottesimo compleanno è mancato mio papà. Al mio compleanno!',
    '“Ho venti anni e faccio sesso a pagamento: voglio avere tanti soldi e fare shopping”… https://t.co/9NbPpmqRnG',
    "Porto i miei settantasette anni come un giovincello.",
    "ricordo ancora i miei ventidue anni",
]

print("######################## Tweets that should match:")
print()
for tweet in tweets_should_match:
    print(tweet_user_age(tweet))

print("\n######################## Tweets that should not match:")
print()
for tweet in tweets_should_not_match:
    print(tweet_user_age(tweet))
# Out:
# ######################## Tweets that should match:
#
# {'tweet': 'ho compiuto 50 anni e non mi importa più niente.', 'age': 50, 'regex_idx': 0}
# {'tweet': 'Ieri ho compiuto 60 anni e mi sento freschissimo.', 'age': 60, 'regex_idx': 0}
# {'tweet': "Tra un mese compio 25 anni e non vedo l'ora.", 'age': 25, 'regex_idx': 1}
# {'tweet': 'Ormai ho 30 anni, damn...', 'age': 30, 'regex_idx': 2}
# {'tweet': 'Finalmente faccio 18 anni!!!', 'age': 18, 'regex_idx': 3}
# {'tweet': 'Cosa vuoi che ne sappia di vecchiaia, sono una 28enne...', 'age': 28, 'regex_idx': 6}
# {'tweet': 'Spengo 40 candeline domani, che emozione.', 'age': 40, 'regex_idx': 4}
# {'tweet': 'Grande fiesta per il mio 22^ comple.', 'age': 22, 'regex_idx': 5}
# {'tweet': 'Grande fiesta per il mio 22^ compleanno.', 'age': 22, 'regex_idx': 5}
# {'tweet': '--------------------------------------------------------', 'age': None, 'regex_idx': None}
# {'tweet': 'Ieri ho compiuto sessanta anni e mi sento freschissimo.', 'age': 60, 'regex_idx': 0}
# {'tweet': "Ieri ho compiuto sessant'anni e mi sento freschissimo.", 'age': 60, 'regex_idx': 0}
# {'tweet': "Tra un mese compio venticinque anni e non vedo l'ora.", 'age': 25, 'regex_idx': 1}
# {'tweet': "Ormai ho trent'anni, damn...", 'age': 30, 'regex_idx': 2}
# {'tweet': 'Finalmente faccio diciotto anni!!!', 'age': 18, 'regex_idx': 3}
# {'tweet': 'Cosa vuoi che ne sappia di vecchiaia, sono una ventottenne...', 'age': 28, 'regex_idx': 6}
# {'tweet': 'Spengo quaranta candeline domani, che emozione.', 'age': 40, 'regex_idx': 4}
# {'tweet': 'Grande fiesta per il mio ventiduesimo comple.', 'age': 22, 'regex_idx': 5}
# {'tweet': 'Grande fiesta per il mio trentunesimo comple.', 'age': 31, 'regex_idx': 5}
# {'tweet': 'Mi sento in diritto di dirlo in quanto sono un ventiduenne.', 'age': 22, 'regex_idx': 6}
# {'tweet': 'HO VENTICINQUE ANNI gioventù', 'age': 25, 'regex_idx': 2}
#
# ######################## Tweets that should not match:
#
# {'tweet': 'Ma che ne so della vita se ho 22 anni?', 'age': None, 'regex_idx': None}
# {'tweet': 'Quando ho 60 anni vado a vivere alle bahamas.', 'age': None, 'regex_idx': None}
# {'tweet': "Lo sapro' meglio io che ho 30 anni in più di te.", 'age': None, 'regex_idx': None}
# {'tweet': '@officialsslazio me faccio 30 anni de galera ma te vengo ammazza co le mani mie VERME BAVOSO', 'age': None, 'regex_idx': None}
# {'tweet': 'Io ho 42 anni di contributi versati, ma "solo" 61 anni di età!', 'age': None, 'regex_idx': None}
# {'tweet': 'Per il lavoro ho 30 anni di industria sulle spalle.', 'age': None, 'regex_idx': None}
# {'tweet': 'Le nuove estetiste cinesi sotto casa mi hanno chiesto se ho 24 anni.', 'age': None, 'regex_idx': None}
# {'tweet': 'Jovanotti: «Ho 50 anni, per me  è un’età assurda»', 'age': None, 'regex_idx': None}
# {'tweet': 'cara non ho 13 anni, e vedo che vi viene molto difficile tenere una discussione in maniera pacata', 'age': None, 'regex_idx': None}
# {'tweet': '“Ho 17 anni e faccio sesso a pagamento: voglio avere tanti soldi e fare shopping”… https://t.co/9NbPpmqRnG', 'age': None, 'regex_idx': None}
# {'tweet': 'Da quando ho compiuto 50 anni non mi importa più niente.', 'age': None, 'regex_idx': None}
# {'tweet': 'Guarda sinceramente vedere un ragazzo ridursi a fare questi commenti da 50enne scapola è triste.', 'age': None, 'regex_idx': None}
# {'tweet': 'l signor "meno male che ho 49 anni".... Lo schifo.', 'age': None, 'regex_idx': None}
# {'tweet': 'ricordo ancora i miei 22 anni', 'age': None, 'regex_idx': None}
# {'tweet': 'Porto i miei 77 anni come un giovincello.', 'age': None, 'regex_idx': None}
# {'tweet': 'Praticamente ho 80 anni', 'age': 80, 'regex_idx': 2}
# {'tweet': '--------------------------------------------------------', 'age': None, 'regex_idx': None}
# {'tweet': 'Ma che ne so della vita se ho ventidue anni?', 'age': None, 'regex_idx': None}
# {'tweet': "Quando ho sessant'anni vado a vivere alle bahamas.", 'age': None, 'regex_idx': None}
# {'tweet': "Lo sapro' meglio io che ho trent'anni in più di te.", 'age': None, 'regex_idx': None}
# {'tweet': '@beatriceletre Fisico da ventenne.\nStai un bijoux🌹😘', 'age': None, 'regex_idx': None}
# {'tweet': "Da quando ho cinquant'anni non mi importa più niente.", 'age': None, 'regex_idx': None}
# {'tweet': 'Perché è il mio compleanno e al mio diciottesimo compleanno è mancato mio papà. Al mio compleanno!', 'age': None, 'regex_idx': None}
# {'tweet': '“Ho venti anni e faccio sesso a pagamento: voglio avere tanti soldi e fare shopping”… https://t.co/9NbPpmqRnG', 'age': None, 'regex_idx': None}
# {'tweet': 'Porto i miei settantasette anni come un giovincello.', 'age': None, 'regex_idx': None}
# {'tweet': 'ricordo ancora i miei ventidue anni', 'age': None, 'regex_idx': None}

# %% [markdown]
# ## Test on 52k tweets

# %%
# read json file
path = "../data/age_classification/users_age_matched_tweets.json"
df = pd.read_json(path)
matches = df.transpose()['matches']
texts = [match[key]['text'] for match in matches for key in match.keys()]
texts
# Out:
# ['@giuliaselvaggi2 Ho 32 anni, saranno 17 anni che tra amici ci si racconta chi fa/facesse cosa, chi fosse questo e quello, di chi fosse quel negozio. Personalmente a me non serviva Gratteri per sapere che il 99% delle persone indagate fosse collusa. È arrivato il momento di ribellarsi',
#  '@iSim86S Guarda sinceramente vedere un ragazzo ridursi a fare questi commenti da 50enne scapola è triste. Il twitt mi è arrivato come consigliato, non sono  venuto a cercarti.\nSo che forse ho sbagliato ma non ce la faccio a stare zitto di fronte a cotanta ridicolezza, mi scuso ugualmente',
#  '@fe_desanctis...se potessi esprimere un desiderio oggi x il mio 37esimo compleanno...sarebbe una foto autografata da te 🤗😍... Buona Pasqua😘',
#  '@pasqlaragione Cose se non ti sta bene Cambia squadra ma non rompere le scatole ogni giorno sempre le stesse cose sono pesanti Pasquale sono pesanti Io non sono un ragazzo Io ho 57 anni bisogna Aver rispetto per le persone che sono più grandi di loro Loro sono ragazzi non capiscono ancora la',
#  '@MMassy86 @86_longo Io non mi lamento mai ho 57 anni cara Cara Purtroppo la realtà di oggi è così bisogna rispettare Chi non vuole rispettare questa realtà e come comando della televisione Schiacci il pulsante giri No basta che non si rompono le scatole agli altri che sono più tranquilli o no',
#  "10 anni DOVREBBE ANDARE A FARE LE STESSE DOMANDE DI M.(attenzione,qui sta x Mattarella)agli stessi Partiti che sostenevano quel furbastro-conquistato dall'EBREZZA DEL POTERE Conte2 il Golpista?qualcuno dovrebbe spiegarmi con tanta,ma tanta,PAZIENZA(HO 73 ANNI E SONO SICILIANO)",
#  "AVREBBERO COLLABORATO,riscuotendo alla fine i 30 denari pattuiti; infatti 1°) da quelle poche e rudimentali nozioni di edilizia imparate nei miei 73 anni di vita,so che il COSTRUTTORE E' UNO SOLO E GLI ALTRI SONO IL DIRETT.DEILAVORI-ILCAPOCANTIERE-I MASTRI-LA PLETORA DEI MANOVALI",
#  '@matteorenzi ho 65 anni disoccupato e in attesa di pensione, se trovi un modo di ricandidarti come premier ti voto,ma il PDora mi fa schifo',
#  'ciao A tutti Sono nuova Su Twitter Mi chiamo Giulia Insigne ho 16 Anni e sono di napoli Amo tanti youtubers tanti cantanti e tifo Napoli https://t.co/jusfgPXRPl',
#  "@rep_bologna L'ho scritta io la lettera a babbo Natale. ma un bel po' di anni fa. Adesso ho 50 anni. Posso cambiare le richieste?",
#  'https://t.co/xUgyYnJlmR\r\nd-34.         Ho fatto 35oo lanci mi sono divertita tantissimo. Ho smesso ho 77 anni',
#  '@skydivemadrid ormai ho fatto 2600 circa lanci. Ora ho 71 anni . Grazie',
#  '@maiobumbum @Adnkronos @GassmanGassmann Anche io ho 67 anni ed ho impiegato lo stesso tempo , nessun problema semplicissimo.',
#  '@CrazyItalianPol @FerdinandoC È il 1994 ho 16 anni \nVado alle superiori \nMio padre alla pagella del primo quadrimestre,visti i voti di merda, mi spiega da operaio con la terza elementare, dell’importanza di non votare sto clown \n#graziepapà',
#  '@StaseraItalia Ho 46 anni e sono cambiati 37 governi in questo periodo, la verità che i politici in Italia pensano solo a farsi notare e fare chiacchiere su ogni azione che fanno,vorrei politici più responsabili che pensano al paese,solo allora andrò a votare',
#  '@FratellidItalia @GiorgiaMeloni Avevo un lavoro a tempo indeterminato grazie alla fornero dopo 19 anni nella stessa azienda il mio hanno licenziato, ora sono senza fissa dimora e senza lavoro ho 58 anni datemi un lavoro nuovo.  Cerco lavoro attivamente ma my deacon che sono vecchio vivo di elemosina',
#  '@vocedelpatriota @FratellidItalia Avevo un lavoro a tempo indeterminato grazie alla fornero dopo 19 anni nella stessa azienda il mio hanno licenziato, ora sono senza fissa dimora e senza lavoro ho 58 anni datemi un lavoro nuovo.  Cerco lavoro attivamente ma my deacon che sono vecchio vivo di elemosina',
#  '@FratellidItalia @FidanzaCarlo @fdieuropa Avevo un lavoro a tempo indeterminato grazie alla fornero dopo 19 anni nella stessa azienda il mio hanno licenziato, ora sono senza fissa dimora e senza lavoro ho 58 anni datemi un lavoro nuovo.  Cerco lavoro attivamente ma my deacon che sono vecchio vivo di elemosina',
#  '@StaseraItalia @GuidoCrosetto Avevo un lavoro a tempo indeterminato grazie alla fornero dopo 19 anni nella stessa azienda il mio hanno licenziato, ora sono senza fissa dimora e senza lavoro ho 58 anni datemi un lavoro nuovo.  Cerco lavoro attivamente ma my deacon che sono vecchio vivo di elemosina',
#  '@RaiStudio24 Date la pensione a chi a perso il lavoro per colpa della, fornero avevo un contratto a tempo indeterminato adesso ho 58 anni. E sono senza fissa dimora.',
#  '@Flower91046311 Avevo un lavoro a tempo indeterminato grazie alla fornero ora sono senza fissa dimora e senza lavoro ho 58 anni datemi un lavoro nuovo.',
#  'Avevo un lavoro a tempo indeterminato adesso ho 58 anni, dammi un lavoro e prendi tu il reddito di cittadinanza.',
#  '@RaiStudio24 @RaiNews Avevo un lavoro a tempo indeterminato grazie alla fornero ora sono senza fissa dimora e senza lavoro ho 58 anni datemi un lavoro nuovo.',
#  '@j_gufo Ieri sera me ne sono mangiate quattro, con quattro tecniche diverse. Ho 41 anni, sono ancora giovane, ma non credo che tra dieci anni smetterò!',
#  'Ho 30 anni e non mi è mai capitato nemmeno quando la mia autoimmune mi aveva portata allo sfascio. Nemmeno ora nonostante il sistema immunitario generatore automatico di autoimmuni e la terapia immunosoppressiva che faccio.\r\nChissà perché... Ah.\r\nSono una 🐭 a 0 dosi. https://t.co/gAj7edDGYV',
#  'ciao ho 34 anni cerco una relazione a lungo terminated: https://t.co/Ofg58FfGV8',
#  'Sei nel letto ed hai in mente “#28giugno”… cos’è? Cosa devo ricordare? \n\nAh, cazzo! \n28/06 - 28/07: \nUltimo mese da 30enne. \n\nHo esattamente 30 giorni per vivere male l’arrivo dei 40 anni.',
#  'Giusto perché faccio 40 anni io è uscita la perimenopausa. https://t.co/g9KGO63nP7',
#  '- 40 anni??? Non ci credo! Sembri più piccola! \n\nChiaro, ho 39 anni 9 mesi e 16 giorni🙄',
#  '@iceberg_inside @n1c0la84 @LuciTheWeirdCat @LoPsihologo Ho 40 anni, lavoro da 15 e nel lavoro vedo un valore non la guerra che vede lei. Si fidi, non ha la verità in tasca.',
#  'Tweet su cosa fare o non fare a 40 anni. \n\nMeno male che ho 39 anni e 7 mesi, altrimenti mi sentirei chiamata in causa.',
#  '- Ciao, che fai?\n- guardo tribune politiche e lavoro a maglia. \n\nPraticamente ho 80 anni.',
#  'Ehi, calmi, calmi, qui stiamo a pregare la fine dell’anno, a scrivere “#addio2020” ma ora mi rendo conto che il #2021 è l’anno dei miei 40 anni!!! 😱😱😱😱\n\nPossiamo fare un 2020bis almeno questo ultimo anno da 30enne lo gestisco meglio?',
#  'Il volto (e la mente) dei Tg nei miei 20 anni, e poi un ottimo presidente del Parlamento europeo. Che tristezza #DavidSassoli',
#  ...]

# %%
# apply the function for age retrieval
tweets = [tweet_user_age(text) for text in texts]
tweets = [tweet for tweet in tweets if tweet['age'] is not None]
random.shuffle(tweets)
tweets[:100]
# Out:
# [{'tweet': '@Leos715 @Andr34_82 @sole202022 Onlyche? Ho 38 anni ma ste cose non capisco proprio.',
#   'age': 38,
#   'regex_idx': 2},
#  {'tweet': '@Sara64301177 Ciao tesoro come va io ho 52 anni',
#   'age': 52,
#   'regex_idx': 2},
#  {'tweet': 'É ufficiale! Ho 25 anni, ma sono un catorcio..',
#   'age': 25,
#   'regex_idx': 2},
#  {'tweet': '@LaurettaTr sono john ho 24 anni vivo a milano tu?',
#   'age': 24,
#   'regex_idx': 2},
#  {'tweet': '@CucchiRiccardo Ho 40 anni, la Repubblica 74.\r\nHo sempre assisistito ad un elettorato preso in giro in Italia. Quale novità?',
#   'age': 40,
#   'regex_idx': 2},
#  {'tweet': '@Manucasy Guarda ho 67 anni, forse sono troppo giovane🤣',
#   'age': 67,
#   'regex_idx': 2},
#  {'tweet': '@funaija Ho 81 anni , mai più guardato Sanremo da almeno 40. Figuriamoci questo carrozzone',
#   'age': 81,
#   'regex_idx': 2},
#  {'tweet': '@Linkiesta Eh no caro @luigidimaio &amp; Co. io ho 40 anni e mi serve un lavoro che non si trova!! sono aitante e preparato: vi conviene mettermi a reddito così pago tasse e contributi alla nostra bella Nazione sennò tra un anno mi dovete dare il reddito di cittadinanza e divento un costo!!',
#   'age': 40,
#   'regex_idx': 2},
#  {'tweet': '@Ale_Bertoldi @ilpdl pres qui sbagli e io che ho 39 anni...che sono vecchio',
#   'age': 39,
#   'regex_idx': 2},
#  {'tweet': "Cerco di ignorare il fatto che fra due mesi compio 21 anni\xa0e la cosa invece che entusiasmarmi mi mette solo un'asia incredibile perché ogni tanto mi sale l'angoscia di non essere riuscita a realizzare nulla nella mia vita",
#   'age': 21,
#   'regex_idx': 1},
#  {'tweet': "@SkyTG24 Ho 50 anni, non sono laureato in ingegneria o matematica ma in giurisprudenza, sono italiano e non so parlare bene l'inglese, peccato, non ci posso andare",
#   'age': 50,
#   'regex_idx': 2},
#  {'tweet': "@an_paci Ho 68 anni. Se da bambino non mi avessero vaccinato, all'epoca obbligatorio e senza no vax, contro la poliomenite oggi potevo essere affetto da conseguenze importanti. Ah! Sono 3 vaccinato, comunista e dall'età di 14 anni contesto in piazza i governi di merda, dal 68 a oggi!",
#   'age': 68,
#   'regex_idx': 2},
#  {'tweet': '@BresciaOfficial Ho 27 anni, costo poco e giocherei con la difesa a 4. Scrivetemi in direct in caso, grazie 😂',
#   'age': 27,
#   'regex_idx': 2},
#  {'tweet': "@MarroneEmma SonoTina ho 48 anni e sono malata di cancro,lotto pelamiacittà control'inquinamentoambientaleeditumori. http://t.co/0JVgfAwrs4",
#   'age': 48,
#   'regex_idx': 2},
#  {'tweet': '@BriatoreFlavio Domani compio 24 anni, fammi gli auguri almeno tu!',
#   'age': 24,
#   'regex_idx': 1},
#  {'tweet': '@Figanghi Lo hai già trovato anche perché ho 39 anni e sono single mai stato sposato senza figli vivo in provincia di Firenze 😉😘',
#   'age': 39,
#   'regex_idx': 2},
#  {'tweet': "@EliChiica io parlo perché ho vent'anni e sono in terza superiore",
#   'age': 20,
#   'regex_idx': 2},
#  {'tweet': '@LaStampa Mi viene la nausea ,ho 40 anni, un 14 enne potrebbe essere mio figlio',
#   'age': 40,
#   'regex_idx': 2},
#  {'tweet': 'Ho 18 anni\r\nSono alto 1.82\r\nSono fisicamente messo apposto\r\nAmo scherzare \r\nSono gay — non mi interessi tu C: http://t.co/ORdpOixNxQ',
#   'age': 18,
#   'regex_idx': 2},
#  {'tweet': 'Ho 23 anni oggi. Sono nata che pesavo 1,080 kg a 29 settimane. Tre case, tre madri, una disabilità e così tante vite da sentirmi già vecchia. Eppure oggi sono felice, anche se temo ancora il buio e la solitudine. Buon compleanno a me.',
#   'age': 23,
#   'regex_idx': 2},
#  {'tweet': '@IlariaBifarini È proprio un gran casino, ho 66 anni con 5 figli e per ora 2 nipoti, sono molto preoccupato per loro. Buon Natale',
#   'age': 66,
#   'regex_idx': 2},
#  {'tweet': 'Biologicamente ho 15 anni, ma il mio cervello ne ha una cinquantina.',
#   'age': 15,
#   'regex_idx': 2},
#  {'tweet': "@FilippoFortuna @guidosesto ma dai c'è monti con fini e casino o ingroia con di Pietro io ho 25 anni e se sono li io non centro ma ora via",
#   'age': 25,
#   'regex_idx': 2},
#  {'tweet': '@RamazzottiEros oggi compio 16 anni mi fai gli auguri?',
#   'age': 16,
#   'regex_idx': 1},
#  {'tweet': '@brigvhtside Ed io che ho 20 anni ne dimostro 15🥺',
#   'age': 20,
#   'regex_idx': 2},
#  {'tweet': '@Italia_Svizzera @molumbe Ho compiuto 50 anni a novembre. ho preferito vaccinarmi, e sono anche io per libertà di scelta. Senza se e senza ma.',
#   'age': 50,
#   'regex_idx': 0},
#  {'tweet': '@nicmax25 Io ho 39 anni e ho imparato Bella Ciao alla scuola elementare dalla maestra il cui nonno aveva fatto la guerra in Russia',
#   'age': 39,
#   'regex_idx': 2},
#  {'tweet': 'Ho 24 anni posso scriverti? — Troppo giovincello https://t.co/sJUoE9pV3U',
#   'age': 24,
#   'regex_idx': 2},
#  {'tweet': '@ginaliodra io  ho 40  anni  di  roma,ti va di conoscerci',
#   'age': 40,
#   'regex_idx': 2},
#  {'tweet': '@davidefaraone On Faraone ho 57 anni visto il terremoto del 1980 e bradisismo Pozzuoli 1983 da domani farò foto ad opere rimaste così dal 1980 e sequestri dopo 40 anni a camorristi quindi voi le stronzate le potete raccontare a chi ha meno di 35 anni e ai disinformati seriali da 25 anni.',
#   'age': 57,
#   'regex_idx': 2},
#  {'tweet': '@_Fucking_Idiot_ scusa ma io ho 33 anni e te quanti anni hai?',
#   'age': 33,
#   'regex_idx': 2},
#  {'tweet': '@wecriedanocean Io ho 18 anni mentre questa persona 23, e gli ho giustamente fatto notare che essere zoccole non significa essere più grandi',
#   'age': 18,
#   'regex_idx': 2},
#  {'tweet': 'Dalla lezione di oggi ho imparato che sono una quarantaquattrenne che sembra una ventenne che si porta male i suoi anni. \r\nE poi abbiamo iniziato il Marketing nell’editoria, perciò seguirò il corso anche a costo di... https://t.co/2zyeUrNHbH',
#   'age': 44,
#   'regex_idx': 6},
#  {'tweet': '@matteorenzi lei sara una brava persona ma io ho 50anni cosa faccio mi coloro di negro x avere un aiuto da te sono italiano',
#   'age': 50,
#   'regex_idx': 2},
#  {'tweet': '#AskSkySport24 Oggi è il mio diciottesimo compleanno....♥♥ che bello essere maggiorenni :) e sempre Forza Pescara!  :*',
#   'age': 18,
#   'regex_idx': 5},
#  {'tweet': '@FratellidItalia @TommasoFoti cioè?  i ho 77 anni, che cosa mi spetta?',
#   'age': 77,
#   'regex_idx': 2},
#  {'tweet': 'prox settimana faccio 18 anni, in sto mese dovevo stare a dieta ma per mille cose che ho fatto non ho potuto, questa cosa mi fa stare male perché avevo perso tipo 3kg, spero di non averli ripresi perché non mi sono potuta pesare #Tiziaparty',
#   'age': 18,
#   'regex_idx': 3},
#  {'tweet': '#pretendounamedaglia perché ho 23 anni ma ogni volta che vado al cinema spendo 10 euro in caramelle a forma di puffo #kisskissmyass',
#   'age': 23,
#   'regex_idx': 2},
#  {'tweet': 'Ho 17 anni  - Non ci credo  http://t.co/dVAXubi6Pi',
#   'age': 17,
#   'regex_idx': 2},
#  {'tweet': "@DemuruDiego @matteosalvinimi Già, io ho 14 anni, ma sono d'accordo con te. Minacce di morte così pesanti non vanno fatte a nessuno. Poi si creano account finti per fare insulti.",
#   'age': 14,
#   'regex_idx': 2},
#  {'tweet': 'Ho 39 anni, ho fatto il classico, l’università, leggo, ascolto ottima musica, sono politicamente schierata ma di fronte ai maneskin mi tocca cedere il passo e ammettere che li adoro, che il singolo è stupendo e Damiano lo canta in modo straordinario. ciao. #xf12',
#   'age': 39,
#   'regex_idx': 2},
#  {'tweet': '@_Meddix_ @NicolaMelloni Non piace perchè lo hanno dipinto come un male assoluto. Sono un percettore, ho 51 anni vivo in Sardegna, per 20 anni e più ho lavorato nel mondo della ristorazione, ora non vengo più preso in considerazione. Troppo grande e troppo qualificato.',
#   'age': 51,
#   'regex_idx': 2},
#  {'tweet': 'Io sono ufficialmente innamorata di De Santis @aerdna__ , se leggi e sei single, ho 19 anni (vado per i 20), sono di Genova e studio economia aziendale e sono appassionatissima anche io di storia. Io ci provo \r\n#lapupaeilsecchioneeviceversa',
#   'age': 19,
#   'regex_idx': 2},
#  {'tweet': '@borghi_claudio Comunque il lavoro non andava toccato a prescindere dagli infami obblighi!\nIo ho 53 anni, ma dei ristoranti, bar, cinema e altro, non me ne frega niente.\nPerò il lavori non andava toccato punto.',
#   'age': 53,
#   'regex_idx': 2},
#  {'tweet': '@SenatoStampa dei loro bravi amici che parlavano di loro. Sapete ho 52 anni ho masticare poco la Politica e dico al Presidente Grasso con 3',
#   'age': 52,
#   'regex_idx': 2},
#  {'tweet': "Non c'è peggior sordo di chi non vuol sentire o comprendere! Se ti interessa ho 63 anni e sono operaio con 36... http://t.co/ocy0LOh67u",
#   'age': 63,
#   'regex_idx': 2},
#  {'tweet': '@ipooh @fabfazio @chetempochefa ho 57 anni sono nata e cresciuta con i pooh',
#   'age': 57,
#   'regex_idx': 2},
#  {'tweet': '@sscnapoli Caro ADL ti consiglio di leggere i tweet che ti ho inviato ed il mio BREVILINEA di oggi sul ROMA. io non sono quel patetico Chiariello di canale 21 o quella volgare della Trieste...ho 70 anni e sono un professionista a tutto campo.',
#   'age': 70,
#   'regex_idx': 2},
#  {'tweet': '“Ho sedici anni e vivo in un carcere\r\nSe c’è un reato commesso là\r\nFuori\r\nÈ stato quello di nascere”',
#   'age': 16,
#   'regex_idx': 2},
#  {'tweet': 'Ora mi devo ricordare che ho 24 anni e non 21 https://t.co/M9Y8JqgFJU',
#   'age': 24,
#   'regex_idx': 2},
#  {'tweet': '@AngelsOfLove12 Io ho 49 anni e sono come te.',
#   'age': 49,
#   'regex_idx': 2},
#  {'tweet': '@SkyTG24 Perché sempre mettere di mezzo complotti!!!!!! Basta…. Si moriva prima, purtroppo, e si muore adesso, purtroppo. Io ho 49 anni e ho fatto tutti i vaccini ed è 1 anno che non ho neanche il raffreddore!!!!! Sono superman?????? Decisamento no!!!!!!',
#   'age': 49,
#   'regex_idx': 2},
#  {'tweet': 'Ma forse sono troppo grande per te ho 25 anni — Tropoo XD http://t.co/Fkm08c8Udq',
#   'age': 25,
#   'regex_idx': 2},
#  {'tweet': 'Adesso ho capito perché #Mal non ha ancora imparato la dizione italiana dopo appena ho 50 anni...ha appena visto Spagna #imigliorianni',
#   'age': 50,
#   'regex_idx': 2},
#  {'tweet': 'Io ho 23 anni e sono una povera sfigata #Verissimo',
#   'age': 23,
#   'regex_idx': 2},
#  {'tweet': "Ciao sono alessandro, ho 42 anni, e ancora mi incazzo con gli amici per trovare una data per l'asta del #Fantacalcio",
#   'age': 42,
#   'regex_idx': 2},
#  {'tweet': '@Ariachetira ricordatevi dei precari della scuola . io ho 40 anni e sono precaria da 15.',
#   'age': 40,
#   'regex_idx': 2},
#  {'tweet': '@PochoLavezzi oggi compio 18 anni!! RT per favoree? &lt;3&lt;3',
#   'age': 18,
#   'regex_idx': 1},
#  {'tweet': 'Ho 27 anni, sono sposata, ho una figlia e sono molto felice. Ma quando vedo "Come d\'incanto" sogno come una bambina! XP',
#   'age': 27,
#   'regex_idx': 2},
#  {'tweet': "@Hartmann_TWT Riflettendo, poiché ho compiuto diciotto anni 40 anni fa, meglio ch'io eviti di dispensar consigli.",
#   'age': 18,
#   'regex_idx': 0},
#  {'tweet': "@pavanmassimo Caro Pavan ho 55 anni e sono  juventino dall' età di 6 anni! Voglio solo sapere la cronaca di quei 10 minuti dell' intervallo a Cardiff!",
#   'age': 55,
#   'regex_idx': 2},
#  {'tweet': 'raga ho un super problema e vi chiedo di aiutarmi :\n\nIo e il mio fidanzato ( con un’altra coppia di amici) volevamo andare a fare un viaggio per natale sempre in italia\n\nMa come lo dico ai miei? Ceh ho 18 anni ma alcune volte sono pesanti',
#   'age': 18,
#   'regex_idx': 2},
#  {'tweet': 'il sesso è una delle cose che vanno riservate al matrimonio, e voi che ve ne pascete tanto prima del tempo siete in peccato mortale.\ndetto questo siete anche un po’ ridicoli, smettetela di pensare SOLO a quello. ho 22 anni e sorpresa, penso ad altro e vivo in castità. https://t.co/weGh0hAfJU',
#   'age': 22,
#   'regex_idx': 2},
#  {'tweet': 'ho 23 anni vivo nel posto più bello del mondo, ho una bella vita fatta di viaggi e concerti ma mi manca il fidanzato archeologo :-(',
#   'age': 23,
#   'regex_idx': 2},
#  {'tweet': '@aledani6774 Volete condividerle in pvt con me du watzapp mi farebbe piacere ho 60 anni mi eccitano odori intimi femminili mutande calze culo figa vi guarderei e mi sego con le vostre foto se vi fa puacere vi do il numero per watzspp',
#   'age': 60,
#   'regex_idx': 2},
#  {'tweet': 'Zio pera tra 2 giorni ho la maturità, ho 19 anni e non so come si tuitta',
#   'age': 19,
#   'regex_idx': 2},
#  {'tweet': "@giorgiazmp @esserefragili io ho 17 anni, non mi faccio completamente schifo, ma preferirei essere un po' più formosa (intendo con un sedere più prosperoso, visto che è quasi inesistente) , ma ormai non posso nemmeno dirlo in giro perché c'è chi potrebbe prendersela, visto che vorrebbe un fisico del-",
#   'age': 17,
#   'regex_idx': 2},
#  {'tweet': 'E quando ti ritrovi a guardare Totally spies su Super ti domandi ma veramente ho 22 anni?😅😂🙊',
#   'age': 22,
#   'regex_idx': 2},
#  {'tweet': 'Ciao a tutti. Mi chiamo Valeria, ho trentaeunsacco di anni e mi affetto le dita insieme al pane.',
#   'age': 30,
#   'regex_idx': 2},
#  {'tweet': '@BrBerlusconi  ho 62 anni sono un ex autore - conduttore televisivo ,esodato  invalido civile da un anno..286 euro mensili, voglio lavorare',
#   'age': 62,
#   'regex_idx': 2},
#  {'tweet': '@enzobianchi7 io ho fibrosi cistica..è  ormai 6 anni che nn riesco piu a camminare e ho 30 anni, non penso arriverò a 33...come spiega questa meschinità se fosse stato il suo gran dio a ridurmi cosi...',
#   'age': 30,
#   'regex_idx': 2},
#  {'tweet': 'ho 20 anni, chi vuole privata? https://t.co/x9Z2mX0KXg',
#   'age': 20,
#   'regex_idx': 2},
#  {'tweet': 'Io ne ho ventuno ed è da anni che ho questo sogno.\nCome fate a vivere senza sensi di colpa, mi chiedo io. https://t.co/otDZVTl0UK',
#   'age': 21,
#   'regex_idx': 2},
#  {'tweet': '@lorenzojova Ciao lorenzo sono un 14 enne innamorato dalla nascita della tua musica...me l ha insegnata proprio la mia mamma... condoglianze',
#   'age': 14,
#   'regex_idx': 6},
#  {'tweet': '@Andrea64523641 @tiodiobene @EnricoLetta Sportivo si giovane no ho 55 anni....penso e ritengo che in questo tipo di situazioni è indispensabile essere TEMPESTIVI... prima si agisce e prima si fronteggia la situazione.',
#   'age': 55,
#   'regex_idx': 2},
#  {'tweet': 'Rispose la ragazza ho tredici anni\ntrentadue perle nella notte\ne se potessi ti sposerei\nper avere dei figli\ncon le scarpe rotte\ngirerebbero questa\ned altre città\nquesta ed altre città\na costruire giostre\ne a vagabondare\nma adesso è tardi\nanche per chiaccherare.',
#   'age': 13,
#   'regex_idx': 2},
#  {'tweet': '@GuidoCrosetto Lo scopre ora solo perché piemontese da generazioni. Io, a Milano, l’ho scoperto nell’infanzia (ho 41 anni), avendo genitori di Barletta. Ricordo ancora i cartelli “non si affitta ai terroni” e la faccia di mio padre.',
#   'age': 41,
#   'regex_idx': 2},
#  {'tweet': "#ottoemezzo l'ospite dice che votano #M5S solo i giovani. NIENTE DI PIÙ FALSO! Ho 56anni e da 2 ogni giorno twitto per Beppe!",
#   'age': 56,
#   'regex_idx': 2},
#  {'tweet': "@ambdlacecilia @molodistIFF @IICKIEVUA @italyinukr @ItalyMFA @CNCcorti Caro Davide, ho 66 anni e 8 mese, nata in Ucraina a Kiev(Kyiv) nel 12 maggio 1954, le mie documente tutti in regola in L'Aquila Questura dal 10 giugno 2002 - sanatoria. Voglio, che voi fermare le mie tutti fotocopie miei documenti dal L'Aquila per INPS di Avezzano per la pensione",
#   'age': 66,
#   'regex_idx': 2},
#  {'tweet': 'Il mio nome è Tair Kaminer, sono israeliana e ho 19 anni. Il 10 gennaio 2016 mi presenterò alle Forze armate per... https://t.co/unvv5qrxlK',
#   'age': 19,
#   'regex_idx': 2},
#  {'tweet': 'Oggi faccio 17 anni e non ho voglia di fare nulla mi sarà lecito avere una giornata di relax? Si spera.',
#   'age': 17,
#   'regex_idx': 3},
#  {'tweet': '"Ho 30 anni. Ho solo 30 anni. È troppo presto perché mi succeda qualcosa. A 30 anni non pensi mai che ti possa succedere qualcosa. Sei un supergiovane nel pieno delle forze. Vuoi e puoi prenderti il mondo e ciò che... https://t.co/7bxiQsK7D6',
#   'age': 30,
#   'regex_idx': 2},
#  {'tweet': '@Ma79Silvia No. Ho 27 anni e non ho intenzione di farli. Tra l’altro mi ripugna vederli sulla pelle di una giovine pulzella.',
#   'age': 27,
#   'regex_idx': 2},
#  {'tweet': 'Ho 28 anni e sto forse piangendo ad ogni scena?\nForse.\nForse sì.\n\n#HarryPotter',
#   'age': 28,
#   'regex_idx': 2},
#  {'tweet': '@lauraboldrini ho 38 anni e ho tre bellissimi figli. peccato che a me lo stato non mi sostenga come potrebbe e dovrebbe.',
#   'age': 38,
#   'regex_idx': 2},
#  {'tweet': '@tripps42 Ma infatti io sto morendo, e ho 35 anni e la so a memoria da sempre',
#   'age': 35,
#   'regex_idx': 2},
#  {'tweet': '#ariachetira sono fuori dal mondo! Ho 26 anni e conosco solo un mio coetaneo che attualmente ha un reddito. I giovani non lavorano, SVEGLIA!',
#   'age': 26,
#   'regex_idx': 2},
#  {'tweet': '@zugrusina @kaya_kaya__ quanti anni ai bella io ho48 anni ti posso dare il mio telefono per sentire la tua bella voce',
#   'age': 48,
#   'regex_idx': 2},
#  {'tweet': 'Io ho 21 anni fuck USA ahah http://t.co/1maLgGwY',
#   'age': 21,
#   'regex_idx': 2},
#  {'tweet': '@flayawa Scusa Fla ho perso  conto, ho 58 anni piccolo imprenditore non ho mai fatto il vaccino, cosa dovrei fare la prima dose a marzo e avanti sino alla quarta nel frattempo mi arriverà la sanzione tra le 100€ e le 1500€ maddai IO NON MI VACCINERÒ MAI.',
#   'age': 58,
#   'regex_idx': 2},
#  {'tweet': 'Lista LEGA NORD per STEFANO RACCAGNI SINDACO\n\nSono Mario Menassi, ho 19 anni, sono uno studente e un orgoglioso... https://t.co/UNoXgEvEfv',
#   'age': 19,
#   'regex_idx': 2},
#  {'tweet': '@lucatelese Caro Luca ho 79 anni sono nata in una famiglia ebrea che per salvarmi mi ha dovuto dare in una famiglia cattolica con altri 4 figli...i miei genitori sono morti in campo di concentramento non li ho mai conosciuti...so che abitavano in un paese vicino al mio e io avevo 8 mesi....',
#   'age': 79,
#   'regex_idx': 2},
#  {'tweet': '@ClaudioGa8 @matteosalvinimi Si certo, tt abbiamo le ns.ragioni. \r\nOggi compio 70anni, tt da sola\r\nE cosi sarà a Natale. I miei figli e nipotini vivono a pochi km da me. \r\nMa  visto che il covid nn ha calendario. \r\nVisto che nn cade dal cielo visibilmente come le💣💣💣NESSUNO lo vede ma quando colpisce😱 \r\nScelgo',
#   'age': 70,
#   'regex_idx': 1},
#  {'tweet': '@uominiedonne Io voglio farmi corteggiare , perché non posso ? Ho 48 anni e sono gay ma vedo che non mi si fa la possibilità https://t.co/HOpw9NbP6c',
#   'age': 48,
#   'regex_idx': 2},
#  {'tweet': "@Rachele_Santi facciamo che il 25 compio 20 anni, il 26 ho L'ESAME. (fixed)",
#   'age': 20,
#   'regex_idx': 1},
#  {'tweet': 'Sono le 23.50 ho 20 anni e ho appena finito di fare i compiti di inglese',
#   'age': 20,
#   'regex_idx': 2},
#  {'tweet': '@SindacatoAsset SONO ISCRITTO AL SINDACATO.HO 63 ANNI.PRIMA DI UNA MISERA PENSIONE , VORREI LAVORARE ALMENO 4 ANNI NELLA SCUOLA , CHE AMO TANTO.',
#   'age': 63,
#   'regex_idx': 2},
#  {'tweet': '@francang1950 Ci mancherebbe altro.. so cosa vuol dire educazione e rispetto,  \nCi si adatta,  finché c’è la si fa’, poi...ho 53 anni  e ho famiglia .. ne ho visto di belle cagate negli anni..ti assicuro che è un casino arrivare al 5 del mese..altro che 27🤕',
#   'age': 53,
#   'regex_idx': 2},
#  {'tweet': "@N_DeGirolamo L'ultima volta che ho avuto l'influenza avevo 12 anni, sono stato molto male, ma era un'influenza. Oggi ho 64 anni, cammino per 10 Km al giorno con la mascherina abbassata e sto da Dio. E allora... dove vogliamo arrivare?",
#   'age': 64,
#   'regex_idx': 2},
#  {'tweet': '@DonBastiano1 @GiacomoGorini sono sopravvissuto per le cure, sono sopravvissuto perché non ho patologie, sono sopravvissuto perché ho 40 anni. Ma credimi tutti siamo bravi a parlarne, ma per chi ci passa non è come raccontare una favoletta. Dalle mie parti si dice così: solo chi cade sente dolore.',
#   'age': 40,
#   'regex_idx': 2}]

# %% [markdown]
# # Retrieve year of birth

# %%
df = pd.read_csv('../data/age_classification/first_1M_tweets.csv',sep=';',quoting=2)['text'].to_list()

# %%
AGE_CHAR = [
    'novantanove',
    'novantotto',
    'novantasette',
    'novantasei',
    'novantacinque',
    'novantaquattro',
    'novantatre',
    'novantadue',
    'novantuno',
    'novanta',
    'ottantanove',
    'ottantotto',
    'ottantasette',
    'ottantasei',
    'ottantacinque',
    'ottantaquattro',
    'ottantatre',
    'ottantadue',
    'ottantuno',
    'ottanta',
    'settantanove',
    'settantotto',
    'settantasette',
    'settantasei',
    'settantacinque',
    'settantaquattro',
    'settantatre',
    'settantadue',
    'settantuno',
    'settanta',
    'sessantanove',
    'sessantotto',
    'sessantasette',
    'sessantasei',
    'sessantacinque',
    'sessantaquattro',
    'sessantatre',
    'sessantadue',
    'sessantuno',
    'sessanta',
    'cinquantanove',
    'cinquantotto',
    'cinquantasette',
    'cinquantasei',
    'cinquantacinque',
    'cinquantaquattro',
    'cinquantatre',
    'cinquantadue',
    'cinquantuno',
    'cinquanta',
    'quarantanove',
    'quarantotto',
    'quarantasette',
    'quarantasei',
    'quarantacinque',
    'quarantaquattro',
    'quarantatre',
    'quarantadue',
    'quarantuno',
    'quaranta',
    'trentanove',
    'trentotto',
    'trentasette',
    'trentasei',
    'trentacinque',
    'trentaquattro',
    'trentatre',
    'trentadue',
    'trentuno',
    'trenta',
    'ventinove',
    'ventotto',
    'ventisette',
    'ventisei',
    'venticinque',
    'ventiquattro',
    'ventitre',
    'ventidue',
    'ventuno',
    'venti',
    'diciannove',
    'diciotto',
    'diciassette',
    'sedici',
    'quindici',
    'quattordici',
    'tredici'
 ]

# remove last letter of each years_in_words entry, in order to match both
# the noun ("ventiquattro") and the adjective ("ventiquattrenne")
AGE_CHAR_SUFFIX_LONG = [year[:-1] for year in AGE_CHAR]

# keep only the shortest form as a first filter
AGE_CHAR_SUFFIX_SHORT = [
    "tredic",
    "quattordic",
    "quindic",
    "sedic",
    "diciasset",
    "diciott",
    "diciannov",
    "vent",
    "trent",
    "quarant",
    "cinquant",
    "sessant",
    "settant",
    "ottant",
    "novant",
]

AGE_DIGIT = list(range(99,12,-1))

# List of regex patterns for matching Twitter posts mentioning the age of the user
# The patterns are built using the age expressed in digits (e.g. "22" for 22)
AGE_DIGIT_PATTERNS = [
    # Matches phrases like "ho compiuto 22 anni" (I just turned 22)
    # but not "quando ho compiuto 22 anni" (when I turned 22)
    # nor "ho compiuto 22 anni di/de" (I have 22 years of)
    r"(?<!quando\s)(?<!quando)ho\s*compiuto\s*(\d{2})\s*anni(?! de)(?! di)(?!de)(?!di)(?! in più)(?! in meno)",
    r"\bcompio\s*(\d{2})\s*anni(?! de)(?! di)(?!de)(?!di)",
    # Matches phrases like "ho 22 anni" (I am 22 years old)
    # but not "da quando/non ho 22 anni" (since I am / I am not 22 years old)
    # nor "ho 22 anni di/de" (I have 22 years of)
    # nor "se ho 22 anni" (if I am 22 years old)
    r"(?<!quando\s)(?<!quando)(?<!non\s)(?<!non)(?<!se\s)(?<!se)ho\s*(\d{2})\s*anni(?! de)(?!de)(?! di)(?!di)(?! in più)(?! in meno)",
    # Matches phrases like "faccio 22 anni" (I am turning 22 years old)
    # but not "faccio 22 anni di/de" (I have 22 years of)
    r"\bfaccio\s*(\d{2})\s*anni(?! de)(?! di)(?!de)(?!di)",
    # Matches phrases like "spengo 22 candeline" (I am blowing 22 candles)
    r"\bspengo\s*(\d{2})\s*candeline",
    # Matches phrases like "il mio 22^ compleanno" (my 22nd birthday)
    r"il\s*mio\s*(\d{2})\^\s*comple(?:anno)?",
    # Matches phrases like "sono un 22enne" (I am a 22-year-old...)
    r"\bsono\s*una?\s*(\d{2})\s*enne",
    # Matches phrases like "i miei 22 anni" (my 22 years)
    # r"\bmiei\s*(\d{2})\s*anni",
]

def return_full_age_char_pattern(age_char):
    """
    Returns a list of regex patterns for matching Twitter posts mentioning the age of the user.
    The patterns are built using the age_char parameter, which is a string containing the
    Italian word for the age of the user (e.g. "ventidue" for 22).
    """
    age_char_patterns = [
            # Matches phrases like "ho compiuto ventidue anni" (I just turned twenty-two)
            # but not "quando ho compiuto ventidue anni" (when I turned twenty-two)
            # nor "ho compiuto ventidue anni di/de" (I have twenty-two years of)
            r"(?<!quando\s)(?<!quando)ho\s*compiuto\s*({}).*\s*anni(?! de)(?!de)(?! di)(?!di)(?! in più)(?! in meno)".format(age_char),
            r"\bcompio\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)".format(age_char),
            # Matches phrases like "ho ventidue anni" (I am twenty-two years old),
            # but not "a quando/non ho ventidue anni" (since I am / I am not twenty-two years old)
            # nor "ho ventidue anni di/de" (I have twenty-two years of)
            # nor "se ho ventidue anni" (if I am twenty-two years old)
            r"(?<!quando\s)(?<!quando)(?<!non\s)(?<!non)(?<!se\s)(?<!se)ho\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)(?! in più)(?! in meno)".format(age_char),
            # Matches phrases like "faccio ventidue anni" (I am turning twenty-two years old)
            r"\bfaccio\s*({}).*\s*anni(?! de)(?! di)(?!de)(?!di)".format(age_char),
            # Matches phrases like "spengo ventidue candeline" (I am blowing twenty-two candles)
            r"\bspengo\s*({})\s*candeline".format(age_char),
            # Matches phrases like "mio ventiduesimo comple/compleanno" (my twenty-second birthday)
            r"il\s*mio\s*{}e?simo\s*comple(?:anno)?".format(age_char),
            # Matches phrases like "sono un ventiduenne" (I am twenty-two-years-old...)
            r"\bsono\s*una?\s*({})\s*e?nne".format(age_char),
            # Matches phrases like "i miei ventidue anni" (my twenty-two years)
            # r"\bmiei\s*({}).*\s*anni".format(age_char),
        ]
    return age_char_patterns

def tweet_user_age(tweet):
    """
    Returns the age of the user who posted the tweet, if the tweet contains a mention of the user's age.
    TODO: the age returned by this function should be compared with the creation date of the tweet.
    """
    if len(tweet) > 0:
        # check if the tweet contains a double digit number, but not in a quoted text
        if re.search(r"\d{2}", tweet):
            if not re.search(r"\".*\d{2}.*\"", tweet) \
                and not re.search(r"\“.*\d{2}.*\”", tweet) \
                and not re.search(r"\«.*\d{2}.*\»", tweet):

                # search for age patterns
                for i, pattern in enumerate(AGE_DIGIT_PATTERNS):
                    matches = re.findall(pattern, tweet, flags=re.IGNORECASE)
                    if matches:
                        return {"tweet": tweet, "regex_type": "age_digit", "regex_idx": i, "age": int(matches[0])}

                # search for year of birth patterns
                for i, pattern in enumerate(YEAR_OF_BIRTH_PATTERNS):
                    matches = re.findall(pattern, tweet, flags=re.IGNORECASE)
                    if matches:
                        birth_year = re.sub('[^0-9]','', matches[0])
                        # if only a double digit year is retrieved, then attach 19 or 20 to it
                        if len(birth_year) == 2:
                            if int(birth_year) < 20:
                                birth_year = "20" + birth_year
                            else:
                                birth_year = "19" + birth_year
                        return {"tweet": tweet, "regex_type": "birth_year", "regex_idx": i, "age": int(birth_year)}

        # check if the tweet contains an age expressed in characters
        if re.search(r"{}".format("|".join(AGE_CHAR_SUFFIX_SHORT)), tweet, flags=re.IGNORECASE):
            # check what age is expressed in the tweet and retrieve its index
            matching_age_char = re.findall(r"{}".format("|".join(AGE_CHAR_SUFFIX_LONG)), tweet, flags=re.IGNORECASE)[0].lower()
            matching_age_char_index = AGE_CHAR_SUFFIX_LONG.index(matching_age_char)
            # check if the age is not in a quoted text
            if not re.search(r"\".*{}.*\"".format(matching_age_char), tweet, flags=re.IGNORECASE) \
                and not re.search(r"\“.*{}.*\”".format(matching_age_char), tweet, flags=re.IGNORECASE) \
                and not re.search(r"\«.*{}.*\»".format(matching_age_char), tweet, flags=re.IGNORECASE):
                # check if also the full form of the age is present in the tweet
                if re.search(r"{}".format(AGE_CHAR[matching_age_char_index]), tweet, flags=re.IGNORECASE):
                    patterns = return_full_age_char_pattern(AGE_CHAR[matching_age_char_index])
                else:
                    patterns = return_full_age_char_pattern(AGE_CHAR_SUFFIX_LONG[matching_age_char_index])
                # search for age statements and retrieve age
                for i, pattern in enumerate(patterns):
                    matches = re.findall(pattern, tweet, flags=re.IGNORECASE)
                    if matches:
                        return {"tweet": tweet, "regex_type": "age_chars", "regex_idx": i, "age": int(AGE_DIGIT[matching_age_char_index])}

    return {"tweet": tweet, "regex_type": None, "regex_idx": None, "age": None}


YEAR_OF_BIRTH_PATTERNS = [
    # Matches sentences like "sono nato nel 1993/93/'93" (I was born in 1993)
    r"\bsono\s*nato\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono del 1993/93/'93" (I am from 1993)
    r"sono\s*del\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono un 1993/93/'93" (I am a 1993)
    r"sono\s*un\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono della generazione 1993/93/'93" (I am generation 1993)
    r"sono\s*della\s*generazione\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono classe 1993/93/'93" (I am class 1993)
    r"sono\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"sono\s*un\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
]

YEAR_OF_BIRTH_PATTERNS_BIO = [
    # Matches sentences like "sono nato nel 1993/93/'93" (I was born in 1993)
    r"\bsono\s*nato\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bnato\s*nel\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bborn\s*in\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono del 1993/93/'93" (I am from 1993)
    r"sono\s*del\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono un 1993/93/'93" (I am a 1993)
    r"sono\s*un\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono della generazione 1993/93/'93" (I am generation 1993)
    r"sono\s*della\s*generazione\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bgenerazione\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    # Matches sentences like "sono classe 1993/93/'93" (I am class 1993)
    r"sono\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"sono\s*un\s*classe\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
    r"\bclasse\s*(20[0-1][0-9]|19[0-9][0-9]|\D\d{2}\s|\D\d{2}$)",
]

# Example tweets
tweets_should_match = [
    "Sono nato nel '52 sai?",
    "Sono nato nel 52 sai?",
    "Sono nato nel 1952 sai?",
    "Sono nato nel 2013 sai?",
    "Sono del '93",
    "Sono del 1966 sai?",
    "Sono del 2000 sai?",
    "Sono un 93",
    "Sono un 2001",
    "Sono un 93 sai?",
    "Sono un '93 sai?",
    "Sono classe '93 sai?",
    "Sono un classe 2000",
    "Ho 20 anni",
    "Ho vent'anni",
]

tweets_should_not_match = [
    "Sono nato nel 1352 sai?",
    "Sono del 1352 sai?",
    "Sono del 2020 sai?",

]

print("######################## Tweets that should match:")
print()
for tweet in tweets_should_match:
    print(tweet_user_age(tweet))

print("\n######################## Tweets that should not match:")
print()
for tweet in tweets_should_not_match:
    print(tweet_user_age(tweet))
# Out:
# ######################## Tweets that should match:
#
# {'tweet': "Sono nato nel '52 sai?", 'regex_type': 'birth_year', 'regex_idx': 0, 'age': 1952}
# {'tweet': 'Sono nato nel 52 sai?', 'regex_type': 'birth_year', 'regex_idx': 0, 'age': 1952}
# {'tweet': 'Sono nato nel 1952 sai?', 'regex_type': 'birth_year', 'regex_idx': 0, 'age': 1952}
# {'tweet': 'Sono nato nel 2013 sai?', 'regex_type': 'birth_year', 'regex_idx': 0, 'age': 2013}
# {'tweet': "Sono del '93", 'regex_type': 'birth_year', 'regex_idx': 1, 'age': 1993}
# {'tweet': 'Sono del 1966 sai?', 'regex_type': 'birth_year', 'regex_idx': 1, 'age': 1966}
# {'tweet': 'Sono del 2000 sai?', 'regex_type': 'birth_year', 'regex_idx': 1, 'age': 2000}
# {'tweet': 'Sono un 93', 'regex_type': 'birth_year', 'regex_idx': 2, 'age': 1993}
# {'tweet': 'Sono un 2001', 'regex_type': 'birth_year', 'regex_idx': 2, 'age': 2001}
# {'tweet': 'Sono un 93 sai?', 'regex_type': 'birth_year', 'regex_idx': 2, 'age': 1993}
# {'tweet': "Sono un '93 sai?", 'regex_type': 'birth_year', 'regex_idx': 2, 'age': 1993}
# {'tweet': "Sono classe '93 sai?", 'regex_type': 'birth_year', 'regex_idx': 4, 'age': 1993}
# {'tweet': 'Sono un classe 2000', 'regex_type': 'birth_year', 'regex_idx': 5, 'age': 2000}
# {'tweet': 'Ho 20 anni', 'regex_type': 'age_digit', 'regex_idx': 2, 'age': 20}
# {'tweet': "Ho vent'anni", 'regex_type': 'age_chars', 'regex_idx': 2, 'age': 20}
#
# ######################## Tweets that should not match:
#
# {'tweet': 'Sono nato nel 1352 sai?', 'regex_type': None, 'regex_idx': None, 'age': None}
# {'tweet': 'Sono del 1352 sai?', 'regex_type': None, 'regex_idx': None, 'age': None}
# {'tweet': 'Sono del 2020 sai?', 'regex_type': None, 'regex_idx': None, 'age': None}

# %%
# test on the first 1M tweets
tweets = [tweet_user_age(text) for text in df]
tweets = [tweet for tweet in tweets if tweet['age'] is not None]
random.shuffle(tweets)

# %%
year_tweets = [tweet for tweet in tweets if tweet['regex_type']=='birth_year']

# %%
year_tweets
# Out:
# [{'tweet': "@Droghiere sono del 2001 e se Bieber prova ad infangare un altro titolo lo ammazzo con l'acido muriatico",
#   'regex_type': 'birth_year',
#   'regex_idx': 1,
#   'age': 2001},
#  {'tweet': "@croccoppini Perché ho vent'anni e sono del 2000",
#   'regex_type': 'birth_year',
#   'regex_idx': 1,
#   'age': 2000},
#  {'tweet': "RT @GAffinito: Le raccomandazioni per l'uso dei #SocialMedia nella PA sono del 2011, ma sono ancora attualissime. Cosa ne pensate? https://…",
#   'regex_type': 'birth_year',
#   'regex_idx': 1,
#   'age': 2011}]
