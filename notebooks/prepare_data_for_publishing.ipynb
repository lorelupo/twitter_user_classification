# %% [markdown]
# ## Create datasets for publishing

# %%
import numpy as np
import pandas as pd
import os
import hashlib

# %%
uc_dir = '/g100_work/IscrC_mental/data/user_classification/'
users_data = '/g100_work/IscrC_mental/data/database/user_geocoded.parquet'

# %%
# Function to anonymize user_id using SHA-256
def anonymize_user_id(user_id):
    return hashlib.sha256(str(user_id).encode()).hexdigest()

# %% [markdown]
# # Training and test dataset of users + features

# %%
# build training dataset
path = uc_dir + 'data_for_models_train.pkl'
df = pd.read_pickle(path)
df_users = pd.read_parquet(users_data)
df_users = df_users[['user_id', 'username', 'full_name', 'location', 'join_year',
       'join_month', 'join_day', 'bio', 'tweets', 'following', 'followers',
       'likes', 'foreign_country', 'region_code']]

#merge 
df_users = df_users[df_users['user_id'].isin(df['user_id'].values)]
df_for_models = df.merge(df_users, on='user_id', how='left')
df_for_models.to_parquet(uc_dir + 'data_for_models_train.parquet')


#anonymize and save for publication
df_for_models.drop(columns=['username', 'full_name'], inplace=True)
df_for_models['user_id'] = df_for_models['user_id'].apply(anonymize_user_id)
df_for_models.to_parquet(uc_dir + 'data_for_publishing/data_for_models_train.parquet')

print(df.shape)
print(df_users.shape)
print(df_for_models.shape)

df_for_models
# Out:
# (19200, 5)
# (19200, 14)
# (19200, 16)
#                                                  user_id  is_male  age  \
# 0      0632dc7a43b1df9806c5a0689b2ea6108debdd99707644...     True   55
# 1      a2fef7ddbcf10e4da73a2ad5ec18cfa9c3cdf25f29fdd1...     True   49
# 2      5093106b2c2dda63b4c77a98a03824a7e8785be51d042c...     True   28
# 3      814de8350c68b4a0f4299841637e3f6e95d1f5f04aaa69...     True   39
# 4      615592a0a79498848ea51557be6be44d9d1f18dfeef6c1...     True   42
# ...                                                  ...      ...  ...
# 19195  50f30a6f40b4c1ee4959f07f99b2d8ae788a2cfeb87130...     True   22
# 19196  ae8c7e447053fd88d33b5cabea37e9cb9bb612be21718c...    False   64
# 19197  9c614370c95e29a0a3db583a414080e047b243521deb82...     True   40
# 19198  534d49bb9f300e14af9bbd948b600f3edc9abc669c648e...     True   63
# 19199  7b0eb7b70c6131e2acdb45fa525558f0bacb1f7393654e...     True   47
#
#                                               masked_bio  \
# 0      Mac user since 1991, working on ICT, physicist...
# 1      Partner di distribuzione Reico. Alimenti di qu...
# 2
# 3                  Avvocato digitale.\r\nDigital Lawyer.
# 4      Ingegnere informatico, 20 anni di esperienza i...
# ...                                                  ...
# 19195
# 19196
# 19197  Odio l'omofobia, i razzisti, i Novax. Non toll...
# 19198
# 19199
#
#                                                long_text  \
# 0      Coraggio, fra 7 mesi sarà il 25 aprile.\nIn te...
# 1      Assistenza Nissan pessima! Mai più Nissan in v...
# 2      Ho finalmente trovato il tempo di ascoltare l'...
# 3      La foto ritrae ciò che posso mangiare dopo ave...
# 4      Perfetto.\nCompagni atei anticlericali non app...
# ...                                                  ...
# 19195  Secondo me l'ha capito meglio di tutti.\nLeone...
# 19196  Ma che grande stronzata,il vino è teschio ai m...
# 19197  , grazie per un'altra bellissima puntata.\nSie...
# 19198  Ma questa è la vostra idea di opposizione?? Gl...
# 19199  @hhembrant Come ti chiami io mi chiamo Gianluc...
#
#                              location  join_year  join_month  join_day  \
# 0      Bologna, Emilia-Romagna, Italy       2006          11        26
# 1             Alba Adriatica, Abruzzo       2007           1         4
# 2                                           2007           1         6
# 3                             Taranto       2007           1         8
# 4                           Benevento       2007           1         8
# ...                               ...        ...         ...       ...
# 19195               Salerno, Campania       2023           1         2
# 19196                                       2023           1         5
# 19197                                       2023           1         8
# 19198                                       2023           1        13
# 19199                                       2023           1        21
#
#                                                      bio  tweets  following  \
# 0      Mac user since 1991, working on ICT, physicist...   20544       1019
# 1      Partner di distribuzione Reico. Alimenti di qu...   11670        989
# 2                                 Una volta ho vomitato.   58980        776
# 3                  Avvocato digitale.\r\nDigital Lawyer.   12144       1001
# 4      Ingegnere informatico, 20 anni di esperienza i...   13134       1269
# ...                                                  ...     ...        ...
# 19195                                                        440         43
# 19196  ho \n64 anni, vedova,con figlio.              ...      48        364
# 19197  Odio l'omofobia, i razzisti, i Novax. Non toll...     757        110
# 19198                                                         29        121
# 19199                                                          9         54
#
#        followers  likes foreign_country  region_code
# 0          12711  24707                          8.0
# 1           3260   4021                         13.0
# 2           3799     79            None          NaN
# 3            667   2691                         16.0
# 4           1055   6671                         15.0
# ...          ...    ...             ...          ...
# 19195         16    294                         15.0
# 19196         70     99            None          NaN
# 19197         34    364            None          NaN
# 19198         10     40            None          NaN
# 19199          4      0            None          NaN
#
# [19200 rows x 16 columns]

# %%
# build test dataset
path = uc_dir + 'data_for_models_test.pkl'
df = pd.read_pickle(path)
df_users = pd.read_parquet(users_data)
df_users = df_users[['user_id', 'username', 'full_name', 'location', 'join_year',
       'join_month', 'join_day', 'bio', 'tweets', 'following', 'followers',
       'likes', 'foreign_country', 'region_code']]

#merge 
df_users = df_users[df_users['user_id'].isin(df['user_id'].values)]
df_for_models = df.merge(df_users, on='user_id', how='left')
df_for_models.to_parquet(uc_dir + 'data_for_models_test.parquet')


# Function to anonymize user_id using SHA-256
def anonymize_user_id(user_id):
    return hashlib.sha256(str(user_id).encode()).hexdigest()

#anonymize and save for publication
df_for_models.drop(columns=['username', 'full_name'], inplace=True)
df_for_models['user_id'] = df_for_models['user_id'].apply(anonymize_user_id)
df_for_models.to_parquet(uc_dir + 'data_for_publishing/data_for_models_test.parquet')

print(df.shape)
print(df_users.shape)
print(df_for_models.shape)

df_for_models
# Out:
# (1119, 5)
# (1119, 14)
# (1119, 16)
#                                                 user_id  is_male  age  \
# 0     04ed4cbff32d86966caafd65acbb9258f26d221a9019b2...     True   47
# 1     28aa0dfce73b8391bbb19398eee5e9a67218c8100ce31e...    False   31
# 2     6d148444a9742bf0ea5030df6b7ad62742ea53e8da5a47...    False   33
# 3     506c95404e5d10b5d7b51d1143b2e8032904f2b610744f...    False   41
# 4     8caebba74ccee420929c55f4abfa77de8cfa080491f250...     True   44
# ...                                                 ...      ...  ...
# 1114  02b043d25f94e1ed44181c0ee54b6feeeeb3d09a15c568...     True   19
# 1115  573ea7d7b41f33717c00396b3d612e3f17ac7f1a3d77e7...    False   33
# 1116  841b48732002157ede869a20f68c66fe0e0f0b3b566bfd...     True   57
# 1117  690c5641e89994476815e2bbac3f78d65881a158ce47c1...    False   19
# 1118  6e4b41cd3515d4c0978d12f3fa03431f87485b33330a8f...    False   47
#
#                                              masked_bio  \
# 0     Con le ruote per terra \r\nSentire il mio pass...
# 1     Quello che gli altri pensano della tua persona...
# 2     Love me? Great. Hate me? Even better. Think I'...
# 3     Sii il cambiamento che vuoi vedere nel mondo M...
# 4                        at home I feel like a tourist.
# ...                                                 ...
# 1114
# 1115
# 1116
# 1117  𝘕𝘢𝘳𝘤𝘰𝘭𝘦𝘱𝘴𝘺 𝘨𝘰𝘵 𝘮𝘦 𝘧𝘦𝘦𝘭𝘪𝘯𝘨 𝘴𝘵𝘢𝘨𝘦 𝘧𝘳𝘪𝘨𝘩𝘵\n\n✧˚ ༘...
# 1118
#
#                                               long_text            location  \
# 0     Lo prendo come un attestato di stima\nPer la s...              Milano
# 1     Lovely zucca\nSta cambiando proprio il tempo\n...               Italy
# 2     Guardi l’ottimo è uno dei motivi per cui ancor...  Cislago, Lombardia
# 3     Io direi per lui, se generalizziamo ci dividia...         Camponogara
# 4     Ore 6, buio pesto. Ribadiamo con forza #TeamOr...       Aleph-on-Sine
# ...                                                 ...                 ...
# 1114                      Get Fortn1t3 from App Valley!
# 1115  Lei non poteva andare perche e personaggio pub...
# 1116  E tantissimi sono contro la GIÒ MELON DONNA FA...
# 1117  È stato un brutto sogno e basta, vero?\nÈ sett...                1q84
# 1118  #amici22 non mi sono mai dispiaciuta come stas...
#
#       join_year  join_month  join_day  \
# 0          2007           6        25
# 1          2007          10        13
# 2          2008           1         2
# 3          2008           3         6
# 4          2008           4         2
# ...         ...         ...       ...
# 1114       2022           2        12
# 1115       2022           3         6
# 1116       2022           4         6
# 1117       2022          10         7
# 1118       2022          12        17
#
#                                                     bio  tweets  following  \
# 0     Con le ruote per terra \r\nSentire il mio pass...    1846       1606
# 1     Quello che gli altri pensano della tua persona...    3510        275
# 2     Love me? Great. Hate me? Even better. Think I'...    2834        348
# 3     Sii il cambiamento che vuoi vedere nel mondo M...    1611        335
# 4                        at home I feel like a tourist.   19556        315
# ...                                                 ...     ...        ...
# 1114  Piacere mi chiamo Maurizio Mennella e ho 19 an...       1        127
# 1115                                                        102         57
# 1116                                                          0         18
# 1117  𝘕𝘢𝘳𝘤𝘰𝘭𝘦𝘱𝘴𝘺 𝘨𝘰𝘵 𝘮𝘦 𝘧𝘦𝘦𝘭𝘪𝘯𝘨 𝘴𝘵𝘢𝘨𝘦 𝘧𝘳𝘪𝘨𝘩𝘵\n\n✧˚ ༘...     214         29
# 1118                                                         91         10
#
#       followers  likes foreign_country  region_code
# 0           956    490                          3.0
# 1           152     17                          NaN
# 2           244     73                          3.0
# 3           446    515                          5.0
# 4          1508  21778                          NaN
# ...         ...    ...             ...          ...
# 1114         10      0            None          NaN
# 1115         10  14471            None          NaN
# 1116          2      0            None          NaN
# 1117         13   3349                          NaN
# 1118          0     39            None          NaN
#
# [1119 rows x 16 columns]

# %% [markdown]
# ## Tweets dataset with tweets' features
# not used in exps but might be useful if people don't want to concatenate tweets

# %%
path = uc_dir + 'data_for_publishing/train.parquet'
df = pd.read_parquet(path)
print(df.shape)

df = df[['user_id', 'tweet_id', 'created_at', 'RT',
       'likes', 'retweets', 'text']]
df.to_parquet(uc_dir + 'train_tweets.parquet')
print(df.shape)

#anonymize and save for publication
df['user_id'] = df['user_id'].apply(anonymize_user_id)
df['tweet_id'] = df['tweet_id'].apply(anonymize_user_id)
df.to_parquet(uc_dir + 'data_for_publishing/train_tweets.parquet')
print(df.shape)

df
# Out:
# (27302637, 15)
# (27302637, 7)
# (27302637, 7)
#                                                     user_id  \
# 0         0632dc7a43b1df9806c5a0689b2ea6108debdd99707644...
# 1         0632dc7a43b1df9806c5a0689b2ea6108debdd99707644...
# 2         0632dc7a43b1df9806c5a0689b2ea6108debdd99707644...
# 3         0632dc7a43b1df9806c5a0689b2ea6108debdd99707644...
# 4         0632dc7a43b1df9806c5a0689b2ea6108debdd99707644...
# ...                                                     ...
# 27302632  592c9d66a9bd3a07adb19e55428c25eb6881efdeb6d417...
# 27302633  592c9d66a9bd3a07adb19e55428c25eb6881efdeb6d417...
# 27302634  592c9d66a9bd3a07adb19e55428c25eb6881efdeb6d417...
# 27302635  592c9d66a9bd3a07adb19e55428c25eb6881efdeb6d417...
# 27302636  592c9d66a9bd3a07adb19e55428c25eb6881efdeb6d417...
#
#                                                    tweet_id  \
# 0         53aa8f3554beb9cd4a24e94d944e8a56476990b13cfef9...
# 1         99ab12f6c4852c69949409499d5cf497b04d1b5079f6e5...
# 2         c8a5331cd9c98d01b650a68e1021cc2fd4a67e29972b6a...
# 3         fef1bc330f3a181bb7fa115af592f1dfe7e0c8acf96b5c...
# 4         44199ff108f32d981623f7b3f5a1e4e9611e1b1e0058ae...
# ...                                                     ...
# 27302632  ffdb6389894e61f0c1f2e4a7e37369ac69c97cffc72c9e...
# 27302633  8f60d107cd7761aa5c03f56e38809886af319557c067cc...
# 27302634  cd62d827f8664ac4feeea806d7bc1140c4b52f2f57b337...
# 27302635  5f5148f2118e9b54ffa8f9bd86bb0e653313009bc62970...
# 27302636  c98ebc3e4338604d3c7ab789acf4594e501f0c6e6a4d27...
#
#                          created_at     RT  likes  retweets  \
# 0         2021-05-18 19:35:20+00:00  False      1         0
# 1         2021-05-20 19:33:45+00:00  False      2         0
# 2         2021-05-22 13:59:11+00:00  False      0         0
# 3         2021-05-22 22:15:53+00:00  False      3         0
# 4         2021-05-22 22:35:41+00:00  False      1         0
# ...                             ...    ...    ...       ...
# 27302632  2021-12-16 00:19:16+00:00  False      0         0
# 27302633  2021-12-16 00:20:54+00:00  False      0         0
# 27302634  2021-12-16 01:14:59+00:00  False      0         0
# 27302635  2021-12-18 00:40:42+00:00  False      0         0
# 27302636  2021-12-18 00:42:51+00:00  False      0         0
#
#                                                        text
# 0         Stasera si segue il primo dibattito sulle prim...
# 1         Stasera si segue il secondo dibattito sulle pr...
# 2         La chiamano “rassegna stampa” per tenere profi...
# 3             Zero punti a UK? #Eurovision #brexit edition!
# 4                                      “This is a GOMBLOT!”
# ...                                                     ...
# 27302632                                     Sei bellissima
# 27302633  Io mi chiamo Alberto e sono italiano di Roma e...
# 27302634  Tanti auguri di Buon Compleanno .Quanti anni fai?
# 27302635  Ciao piacere di conoscerti mi chiamo Alberto s...
# 27302636                                         Bellissimo
#
# [27302637 rows x 7 columns]

# %%
path = uc_dir + 'data_for_publishing/test.parquet'
df = pd.read_parquet(path)
print(df.shape)

df = df[['user_id', 'tweet_id', 'created_at', 'RT',
       'likes', 'retweets', 'text']]
df.to_parquet(uc_dir + 'test_tweets.parquet')
print(df.shape)

#anonymize and save for publication
df['user_id'] = df['user_id'].apply(anonymize_user_id)
df['tweet_id'] = df['tweet_id'].apply(anonymize_user_id)
df.to_parquet(uc_dir + 'data_for_publishing/test_tweets.parquet')
print(df.shape)

df
# Out:
# (1571178, 15)
# (1571178, 7)
# (1571178, 7)
#                                                    user_id  \
# 0        5b5c01c68089b43b76bebfb4715f28fd9c3de023819993...
# 1        5b5c01c68089b43b76bebfb4715f28fd9c3de023819993...
# 2        5b5c01c68089b43b76bebfb4715f28fd9c3de023819993...
# 3        5b5c01c68089b43b76bebfb4715f28fd9c3de023819993...
# 4        5b5c01c68089b43b76bebfb4715f28fd9c3de023819993...
# ...                                                    ...
# 1571173  bb678485ce6e690a7bf72e86960b88d8b1360086cef3ab...
# 1571174  bb678485ce6e690a7bf72e86960b88d8b1360086cef3ab...
# 1571175  bb678485ce6e690a7bf72e86960b88d8b1360086cef3ab...
# 1571176  bb678485ce6e690a7bf72e86960b88d8b1360086cef3ab...
# 1571177  bb678485ce6e690a7bf72e86960b88d8b1360086cef3ab...
#
#                                                   tweet_id  \
# 0        132b55ee051057bf9345a326b2999cf46cce68874c5eb8...
# 1        c57c3990a0bb53374dc14e0c9e8dd6ebcca32eee70d14b...
# 2        b452e01aa675c4146951ce7b27ce2ba4c00b9d7752a474...
# 3        efbe267b8c041a0039c6daabf53f1ca6b005019b5613ac...
# 4        6dc82b4d014005380540f2528ef082fe744b6326a00bb7...
# ...                                                    ...
# 1571173  43b320b461bced5441c0b228de41ac29c8cbc851f09141...
# 1571174  59f17601e857292052562643386560288e057ef4533921...
# 1571175  56828c2266abf03a8c97983f4a2dce51b85ee83720af1a...
# 1571176  2d67435fba6a1aac80f398bde9d897b4b7cbd8f78751c0...
# 1571177  442b80104b2a41ede1b4dfa49774ae5e46d2ef976cc107...
#
#                         created_at     RT  likes  retweets  \
# 0        2021-06-07 17:03:12+00:00  False     29         1
# 1        2021-07-05 20:48:35+00:00  False      5         0
# 2        2021-07-25 19:21:41+00:00  False      0         0
# 3        2021-07-29 08:48:28+00:00  False      0         0
# 4        2015-03-20 07:54:48+00:00   True      0        15
# ...                            ...    ...    ...       ...
# 1571173  2017-12-25 06:03:19+00:00  False      0         0
# 1571174  2018-01-11 13:05:32+00:00  False      1         1
# 1571175  2018-01-11 13:12:55+00:00  False      1         0
# 1571176  2018-01-11 13:17:26+00:00  False      1         0
# 1571177  2018-01-11 13:59:06+00:00   True      0         1
#
#                                                       text
# 0        Meglio fidarsi del proprio istinto, mio padre ...
# 1        Mi hai aperto una ferita …avevo accantonato il...
# 2                                             O in Sicilia
# 3        Salve, avrei bisogno di contattare un operator...
# 4                  L’eclissi accende i prezzi dell’energia
# ...                                                    ...
# 1571173  Salve signor Silvio Berlusconi io e mia moglie...
# 1571174  Salve signor Silvio Berlusconi mi chiamo Giuse...
# 1571175  Sé c'è qualche persona che mi possono dare una...
# 1571176  Ciao sono sempre in sono su WhatsApp lo stato ...
# 1571177  Salve signor Silvio Berlusconi mi chiamo Giuse...
#
# [1571178 rows x 7 columns]

# %% [markdown]
# ## Hash profile pics filenames

# %%
# Function to anonymize filenames using SHA-256
def anonymize_filename(filename):
    name, ext = os.path.splitext(filename)
    hashed_name = hashlib.sha256(name.encode()).hexdigest()
    return f"{hashed_name}{ext}"

# Directory containing the images
image_directory = uc_dir + "data_for_publishing/profile_pics/test/"

# List all files in the directory
files = os.listdir(image_directory)

# Process each file
for filename in files:
    # Get the full path of the current file
    full_path = os.path.join(image_directory, filename)
    
    # Skip if it's not a file
    if not os.path.isfile(full_path):
        continue

    # Generate the anonymized filename
    anonymized_name = anonymize_filename(filename)
    
    # Get the full path for the new filename
    anonymized_path = os.path.join(image_directory, anonymized_name)
    
    # Rename the file
    os.rename(full_path, anonymized_path)

print("Filenames have been anonymized.")
# Out:
# Filenames have been anonymized.

# %%
# Directory containing the images
image_directory = uc_dir + "data_for_publishing/profile_pics/train/"

# List all files in the directory
files = os.listdir(image_directory)

# Process each file
for filename in files:
    # Get the full path of the current file
    full_path = os.path.join(image_directory, filename)
    
    # Skip if it's not a file
    if not os.path.isfile(full_path):
        continue

    # Generate the anonymized filename
    anonymized_name = anonymize_filename(filename)
    
    # Get the full path for the new filename
    anonymized_path = os.path.join(image_directory, anonymized_name)
    
    # Rename the file
    os.rename(full_path, anonymized_path)

print("Filenames have been anonymized.")
# Out:
# Filenames have been anonymized.
